# %% [markdown]
# # Stolen Cycles: A Bicycle Theft LocalizationTool
#
# ## DATS 6103 Individual Project 3 : Mariko McDougall
#
# ### Statement of Purpose
#
# This is a tool for users to take advantage of the Bike Index to visualize areas of high bike theft. While some "rough" areas can present obvious risks of bike theft, more affluent or tourist-heavy areas can also present a hidden risk to cyclists.  As bicycle thefts tend to be underreported crimes, they also frequently are not reflected in regional crime statistics.
#
# This tool allows users to input their current location, and receive the location and recency of nearby bike thefts. This allows users to make informed decisions prior to leaving their cycle unattended.
#
# This analysis was performed for GWU's DATS 6103 - Introduction to Data Mining.
# The purpose of this analysis is to extract and examine data using publicly available datasets and draw conclusions, as well as make predictions using the findings.
#
# All data sourcing, wrangling and analysis was performed in python using publicly available libraries.
#
#
# ### Data Source
#
# The data for this project was aquired from the Bike Index [https://bikeindex.org/], a nonprofit bike registration orginization that allows users to document their bikes so that in the event they are stolen they are easier to identify and recover.
#
# An aspect of this service is the ability to mark a pre-registered bike as stolen, making the address and circumstances of the theft available to the public.
#
# The Bike Index has data provided by cyclists in cities across the United States, and is highly open to developer interaction with the data.

# %% [markdown]
# ## Web Scraping the Bike Index
#
#
# ### Search Page
#
# The first portion of the web scraper queries each page of the
# <img src="Search_page_location.png">
#
# If the location contains the string " - US", the webscraper will add the URL of that entry to the list.
# Once all entries have been parsed, the list is passed on to the second protion.
#
# <img src="Theft_details_page.png">

# %%
#Non-Specific Imports
import os
import re
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import concurrent.futures as cf
from tqdm import tqdm

#Web-Scraping Imports
import requests
from bs4 import BeautifulSoup

#Geocoders
from geopy.geocoders import Nominatim
from geopy.geocoders import Photon

#Set Pandas options
pd.set_option('display.max_columns', 10)
pd.options.mode.chained_assignment = None 

#Set the working directory
wd=os.path.abspath('C://Users//Mariko//Documents//GitHub//BicycleTheft-DATS6103')
os.chdir(wd)

# %%
def download_batch_url(url_list):
    """
    Download a batch of urls, and return dataframe of the resulting data.
    Multi-threaded, cuts download times by 3/4
    url_list: a list of urls of stolen bikes
    """
    
    def find_attribute(att_string,result_table):
        """
        Checks to see if a given attribute is in the table, and returns the value if it is available.
        """
        #If the data row exists in the reported data, download. Else, "None".
        try:
            text = result_table.find(string=re.compile(att_string)).parent.next_sibling 
            return text
        except:
            return 'None'


    def bike_download(url):
        """
        Downloads the information from the bike URL
        Bike page is variable depending on what information was reported to the site
        Minimum, the bike ID, date of theft, city and country.
        """    
        
        #Download the page
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        
        #Specifically take the theft reporting information
        results = soup.find("ul", {"class":"attr-list separate-lines"})
        
        #Initialize the catch dictionary, and capture the bike ID
        catch={'Bike ID': url.split('/bikes/')[1]}
        
        #Capture all other info, if present
        for attr in ['Location', 'Locking description', 'Locking circumvented', 'Date stolen', 'Police report']:
            catch[attr]=find_attribute(attr, results)
        return catch
    
    #Multi-threaded downloader for the list of URLs compiled by the search_page_downloader function
    with cf.ThreadPoolExecutor() as executor:
        results=[executor.submit(bike_download, url) for url in url_list]

    catch=[f.result() for f in results]
    
    #Concatinate the results into a dataframe
    download_df=pd.DataFrame(catch)
    
    return download_df

# %%
def search_page_downloader(page_url):
    """
    Download all the bikes per search page that have a US location listed
    Does not download non-us or non location specified thefts
    """
    
    #Download the "search bikes" page
    page = requests.get(page_url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #Get the table of bike thefts, and look through by theft
    results = soup.find_all("div", {"class":"bike-information multi-attr-lists"})
    
    clean_urls=[]
    
    #Check to make sure the location is present in the theft report
    for result in results:
        theft_location= result.find(string=re.compile('Location')).parent.next_sibling
        
        #Only append URLS for downloading if the city is specified. 
        #If city is indicated, location will terminate in "- US", and if location is only "US", there is no - .
        if '- US' in theft_location:
            clean_urls.append(result.find('a').get('href'))
    
    #Download the batch of urls
    df_page=download_batch_url(clean_urls)
    
    return df_page

# %%
def get_final_page():
    """
    Scrapes the link to the final page of logged bikes from the last page button (">>") , 
    to reconstruct the total number of pages to scrape for a full database download.
    This link changes when new bikes are added, so the scraper cannot use a static address.
    """
    url='https://bikeindex.org/bikes?stolenness=stolen'
    
    #Download the page
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #Find the last page of the stolen bikes
    results = soup.find("div", {"class":"pagination"})
    last_page=results.find_all('a')[-1].get('href')
    last_page=last_page.split('page=')[1].split('&stolen')[0]
    
    return int(last_page)

# %%
def full_download(interval=10, max_page=20, min_page=2):
    """
    Download pages of the search stolen bkes pages
    interval: How many pages of search to download simultaniously (~10 bikes per page)
    max_page: What search page to stop downloading (the larger number is older reports)
    min_page: What search page to start downloading - Useful if download gets interrupted.
    """
    
    problem_sections=[] 
    
    #Start the overall clock 
    overall_start=time.perf_counter()
    
    i=min_page
    while i < max_page:
        
        try:
            #Generate all URLs for this section 
            if i+interval > max_page:
                i_end=max_page+1
            else:
                i_end=i+interval
                
            url_list=['https://bikeindex.org/bikes?page='+str(i)+'&stolenness=all' for i in range(i,i_end)]
                
            #Start clock for this section    
            section_start=time.perf_counter()
            
            #Thread the page downloads
            with cf.ThreadPoolExecutor() as executor:
                results=[executor.submit(search_page_downloader, url) for url in url_list]
            
            #Concatinate the chunk's results
            catch=[f.result() for f in results]
            df_downloaded=pd.concat(catch)
            
            #For privacy, change the report number to a binary value
            df_downloaded['Police report'] = df_downloaded['Police report'] != 'None'
            df_downloaded['Police report'] = df_downloaded['Police report'].replace({True:'Reported', False:'None'})
            
            #Save the file
            df_downloaded.to_csv(f'./Data/Individual Pages/Page {i}-{i_end}.csv')
            
            section_finish=time.perf_counter()
            
            print(f'                    -----------                \n')
            print(f'Section {i}-{i_end} finished in {round(section_finish-section_start,5)} seconds')    
            print(f'\n                    -----------                \n')
            
        except:
            problem_sections.append(f'{i} - {i_end}')
            print(f'\nERROR: {i} - {i_end}\n')
        
        i+=interval
    
    #Overall time    
    overall_finish=time.perf_counter()
    print(f'Overall finished in {round(overall_finish-overall_start,5)} seconds')   
    
    return problem_sections

# %% [markdown]
# ## Process the Downloaded Data

# %%
#Load all files in the individual pages download folder
x=[pd.read_csv('./Data/Individual Pages/'+i, index_col=0) for i in os.listdir('./Data/Individual Pages')]

#Concatinate the loaded pages
df_base=pd.concat(x).reset_index(drop=True)

# %%
#Preview our downloaded data
df_base.head()
# Out:
#   Bike ID                             Location Locking description  \
# 0  763494     62 Rugby Road, Buffalo, NY 14216               Other
# 1  773525  Alameda & Bannock, Denver, CO 80223              U-lock
# 2  756339                   Portland, OR 97206          Cable lock
# 3  763020                    Seattle, WA 98105              U-lock
# 4  762966                  Edmonton, T5e 0L1,                 None
#
#                      Locking circumvented Date stolen Police report
# 0  Other situation, please describe below   2020.6.15      Reported
# 1    Lock is missing, along with the bike   2020.6.15          None
# 2     Lock was cut, and left at the scene   2020.6.15          None
# 3    Lock is missing, along with the bike   2020.6.15          None
# 4                                    None   2020.6.15      Reported

# %%
def clean_bike_IDs(df):
    """
    Clean up the Bike IDs - They are directly taken from the URLs, and some old entries have small string fragments.
    """
    #Clean the IDs - split off the language string from the ID and rejoin the column
    df_cleaned = df['Bike ID'].astype(str)
    df_cleaned = df_cleaned.str.split('?', n=2, expand=True)
    df_cleaned = df_cleaned.iloc[:, 0].astype(int)
    
    df['Bike ID'] = df_cleaned
    
    return df


def clean_address(df):
    """
    Clean Address inputs, and add a binary column if a full address was provided, not just a city
    Also add a city and state column based on the entered location.
    """
    
    #Remove Edmonton, Alberta. Not sure how it consistantly gets in.
    df=df[~df['Location'].str.contains('Edmonton') ]
    
    #Comma placement is standardized on the site, can be used to parse the locations
    df['Full Address'] = df['Location'].str.count(',')
    
    #Remove all the single name locations as they cannot be parsed, eg "Florida"
    df = df[df['Full Address'] > 0]
    
    #Convert to binary if there is a full address or just city
    df['Full Address'] = df['Full Address'] > 1
    
    #Extract city and state
    df['City']=df['Location'].str.rsplit(',', n=2).str[-2].str.strip()
    df['State']=df['Location'].str.extract(r'(\b[A-Z][A-Z]\b)')
    
    #Drop rows that didn't parse state correctly
    df=df.dropna()
    
    return df


def add_datetime(df_in):
    """
    Adds a datetime column to the dataframe by parseing the input date string
    Original date column is a string of format "YYYY.M(M).D(D)", where month and day are NOT zero padded, 
    which cannot be parsed by pd.to_datetime().
    
    Returns the modified dataframe
    """
    
    df=df_in.copy()
    
    datetime=[]
    
    #Parse the date stolen from the date column.
    #Splits the string on '.', and zfill to create a zero padding.
    for i in df['Date stolen']:
        if i == 'None':
            datetime.append(np.nan)
        else:
            date=i.split('.')
            date=date[0]+date[1].zfill(2)+date[2].zfill(2)
            datetime.append(date)
    
    df['DateTime']=pd.to_datetime(datetime, format='%Y%m%d')

    return df

# %%
#Process the IDs, Addresses and Dates

df_base=clean_bike_IDs(df_base)
df_base=clean_address(df_base)
df_base=add_datetime(df_base)

# %%
df_base.head()
# Out:
#    Bike ID                             Location Locking description  \
# 0   763494     62 Rugby Road, Buffalo, NY 14216               Other
# 1   773525  Alameda & Bannock, Denver, CO 80223              U-lock
# 2   756339                   Portland, OR 97206          Cable lock
# 3   763020                    Seattle, WA 98105              U-lock
# 5   780023                New Orleans, LA 70119                None
#
#                      Locking circumvented Date stolen Police report  \
# 0  Other situation, please describe below   2020.6.15      Reported
# 1    Lock is missing, along with the bike   2020.6.15          None
# 2     Lock was cut, and left at the scene   2020.6.15          None
# 3    Lock is missing, along with the bike   2020.6.15          None
# 5                                    None   2020.6.15          None
#
#    Full Address         City State   DateTime
# 0          True      Buffalo    NY 2020-06-15
# 1          True       Denver    CO 2020-06-15
# 2         False     Portland    OR 2020-06-15
# 3         False      Seattle    WA 2020-06-15
# 5         False  New Orleans    LA 2020-06-15

# %%
def remove_apartments(address_list):
    """
    Removes several common appartment labels that interfere with the location search
    Includes "Apt ___", 'Unit ____,  # ____, and just the number between two commas (eg, ', 201,)
    """
    
    #Create a sepreate index to track which entries need to be solved -  removing entries from the main index
    #during loops causes errors in the tracking
    unsolved_index=list(range(len(address_list)))
    
    
    def pattern_loop(pattern, address_list, unsolved_list):
        """
        Applies a regex pattern to the list of addresses, and removes
        matching elements from the addresses if found, returning the modified addresses
        and the list of addresses that still need to be fixed
        
        """
    
        internal_fixed=[]

    
        #Search for the regex pattern in each entry
        for addr_index in unsolved_list:
            addr_str=address_list[addr_index]
            match= pattern.search(addr_str.title())
            try:
                #If a match was found, eliminate the matched substring
                substring=match[0]
                addr_new=addr_str.title().replace(substring, '')
                
                #Replace the string in the list, and track the index
                address_list[addr_index] = addr_new
                internal_fixed.append(addr_index)
                
                print(addr_str)
                print(addr_new)
                print()
    
            except:
                pass
        
        #Remove elements from the unsolved list that were solved - must do at the end or the iteration breaks
        if len(internal_fixed)>0:
            unsolved_list=list(filter(lambda i: i not in internal_fixed, unsolved_list))
    
        return address_list, unsolved_list
    
    
    print(f'\nApartments with the word Apartment or Unit')
    print(f'---------------------\n')
    
    #Removes the apartments that have the prefix "Apt" or "Unit"
    pattern=re.compile("\W([Aa]pt|[Uu]nit)[\w|\W]+?[,]")
    address_list, unsolved_index = pattern_loop(pattern, address_list, unsolved_index)


    
    print(f'\nApartments with the prefix #_____')
    print(f'---------------------\n')
    
    #Removes the apartments that have the prefix #_____
    pattern=re.compile("[#][\w|\W]+?[,]")
    address_list, unsolved_index = pattern_loop(pattern, address_list, unsolved_index)

    
    print(f'\nApartments with format , #### , ')
    print(f'---------------------\n')
    
    #Removes the apartments that have just the number between two commas
    pattern=re.compile("[,][\W|0-9]+?[,]")
    address_list, unsolved_index = pattern_loop(pattern, address_list, unsolved_index)

    
    print(f'\nApartments with the word Ste (studio/suite)')
    print(f'---------------------\n')
    
    #Removes the apartments that have just the number between two commas
    pattern=re.compile("\s[Ss]te[\s,.][\w|\W]+?[,]")
    address_list, unsolved_index = pattern_loop(pattern, address_list, unsolved_index)


    return address_list

# %%
def modify_directions(address_list):
    """
    Both lengthens and removes common directional abbrviations (eg NE for NorthEast)
    Returns both lists - use lengthened first, then shortened for maximum specificity
    """
    
    def directions_pattern_loop(pattern, address_list):
        """
        Applies a regex pattern to the list of addresses, and removes
        matching elements from the addresses if found, returning the modified addresses
        and the list of addresses that still need to be fixed
        
        """
    
        internal_long=[]
        internal_short=[]
    
    
        #Search for the regex pattern in each entry
        for addr_str in address_list:
            match= pattern.search(addr_str.title())
            try:
                #If a match was found, eliminate the matched substring
                substring=match[0]
                mod_substring = substring.upper()
    
                #Replace all abbreviations with the full word            
                for initial, full in {"N":"North", "S":"South", "E":"East", "W":"West",}.items():
                    mod_substring = mod_substring.replace(initial.upper(), full)
                
                #Replace the original substring with the modified version
                addr_new=addr_str.title().replace(substring, mod_substring)
                internal_long.append(addr_new)
                
                print(addr_str)
                print(addr_new)
                
                #Also append a version without the direction, in case the first doesn't work
                addr_new=addr_str.title().replace(substring, ' ')
                internal_short.append(addr_new)
    
                print(addr_new)
                print()
    
            except:
                #If match not found, then add to list regardless
                internal_long.append(addr_str)
                internal_short.append(addr_str)
    
        return internal_long, internal_short
    
    
    print(f'\nAddresses with Directional Abbreviations')
    print(f'---------------------\n')
    
    #Create three lists, one with the directions lengthened, one with them cropped out, and a continuing list
    pattern=re.compile("\s[NESWnesw]{1,2}\s")
    out_fixed_long, out_fixed_short = directions_pattern_loop(pattern, address_list)
    
    
    return out_fixed_long, out_fixed_short

# %%
df_loc = df_base.copy()


df_loc["Modified Location"] = remove_apartments(df_loc["Location"].tolist())
df_loc["Modified Location"], df_loc["Modified Shortened Location"] = modify_directions(df_loc["Modified Location"].tolist())
# Out:
# Apartments with the word Apartment or Unit
# ---------------------
#
#  2865 W. Elliott Dr, Apt A308, Spokane, WA 99224
#  2865 W. Elliott Dr, Spokane, Wa 99224
#
# 14 Lexington Ave Apt 2 C, Buffalo, NY 14222
# 14 Lexington Ave Buffalo, Ny 14222
#
# 14 Edgewater Towne Center Unit 3A, Edgewater, NJ 07020
# 14 Edgewater Towne Center Edgewater, Nj 07020
#
# 333 Sunol St, Unit 313, San Jose, CA 95126
# 333 Sunol St, San Jose, Ca 95126
#
# South 6th Street and Virginia Street from Apt #264 balcony, San Jose, CA 95112
# South 6Th Street And Virginia Street From San Jose, Ca 95112
#
# 2140 nw Kearney St apt414, Portland, OR 97210
# 2140 Nw Kearney St Portland, Or 97210
#
# 1600 Hillcrest drive apt 2, Manhattan, KS 66502
# 1600 Hillcrest Drive Manhattan, Ks 66502
#
# 2121 3rd Street Unit 0217, San Francisco, CA 94107
# 2121 3Rd Street San Francisco, Ca 94107
#
# 39 Symphony Rd, Unit C, Boston, MA 02115
# 39 Symphony Rd, Boston, Ma 02115
#
# 2202 W NORTH LOOP BLVD APT 232, Austin, TX 78756
# 2202 W North Loop Blvd Austin, Tx 78756
#
# 1401 S 10th St Apt 1, Waco, TX 76706
# 1401 S 10Th St Waco, Tx 76706
#
# 3121 Main Street apt #153, Philomath, OR 97370
# 3121 Main Street Philomath, Or 97370
#
# 2520 S 8th St apt 401, Minneapolis, MN 55454
# 2520 S 8Th St Minneapolis, Mn 55454
#
# Calypso Dr & Via Medici, Aptos, CA 95003
# Calypso Dr & Via Medici, Ca 95003
#
# 2348 N Harding Ave, Apt. 2, Chicago, IL 60647
# 2348 N Harding Ave, Chicago, Il 60647
#
# 566 Prospect Street Unit 103, Seattle, WA 98109
# 566 Prospect Street Seattle, Wa 98109
#
# 19523 AURORA AVE N UNIT 2 SHORELINE WA SHORELINE, WA, Shoreline, WA 98177
# 19523 Aurora Ave N Wa, Shoreline, Wa 98177
#
# 13488 Maxella avenue Apt 566, Marina Del Rey, CA 90292
# 13488 Maxella Avenue Marina Del Rey, Ca 90292
#
# 732 Lamont St NW APT 301, Washington, DC 20010
# 732 Lamont St Nw Washington, Dc 20010
#
# 801 Sugaree Ave, Apt 2131, Austin, TX 78757
# 801 Sugaree Ave, Austin, Tx 78757
#
# 121 E. 28th St., Apt. A, Vancouver, WA 98663
# 121 E. 28Th St., Vancouver, Wa 98663
#
# 9613 Grove Crest Ln Apt 1712, Charlotte, NC 28262
# 9613 Grove Crest Ln Charlotte, Nc 28262
#
# 950 Mountain View Dr, Apt 14, Lafayette, CA 945493703
# 950 Mountain View Dr, Lafayette, Ca 945493703
#
# 4311 Alcove Ave unit 14, Studio City, CA 91604
# 4311 Alcove Ave Studio City, Ca 91604
#
# 645 NW portlave ave, unit 4, Bend, OR 97703
# 645 Nw Portlave Ave, Bend, Or 97703
#
# 4525 NE Fremont St, Apt 403, Portland, OR 97213
# 4525 Ne Fremont St, Portland, Or 97213
#
# 471 Acalanes Drive, Unit 24, Sunnyvale, CA 94086
# 471 Acalanes Drive, Sunnyvale, Ca 94086
#
# 1013 Maplehurst Court, Apt. 7, Knoxville, TN 37902
# 1013 Maplehurst Court, Knoxville, Tn 37902
#
# 9425 s riverside dr apt 1634, Sandy, UT 84070
# 9425 S Riverside Dr Sandy, Ut 84070
#
# 9425 s riverside dr apt 1634, Sandy, UT 84070
# 9425 S Riverside Dr Sandy, Ut 84070
#
# 2152 Avenue F Apt 1, Wichita Falls, TX 76309
# 2152 Avenue F Wichita Falls, Tx 76309
#
# 1910 Garces hwy apt a1, Delano, CA 93215
# 1910 Garces Hwy Delano, Ca 93215
#
# 306 E 12TH ST, UNIT 806, Kansas, MO 64106
# 306 E 12Th St, Kansas, Mo 64106
#
# 2828 Silverplume Drive, Apt C1, Fort Collins, CO 80526
# 2828 Silverplume Drive, Fort Collins, Co 80526
#
# 1406 NW 62nd St Apt 101, Seattle, WA 98133
# 1406 Nw 62Nd St Seattle, Wa 98133
#
# 1501 Stallings Drive Apt 58, College Station, TX 77840
# 1501 Stallings Drive College Station, Tx 77840
#
# 4011 Whitman Ave N Apt 301, Seattle, WA 98103
# 4011 Whitman Ave N Seattle, Wa 98103
#
# 1115 17th ave, Apt 104, Seattle, WA 98122
# 1115 17Th Ave, Seattle, Wa 98122
#
# 1425 Spring Street, Apt 1202, Seattle, WA 98104
# 1425 Spring Street, Seattle, Wa 98104
#
# 4261 Hunter St, Apt 3f, Long Island City, NY 11101
# 4261 Hunter St, Long Island City, Ny 11101
#
# 1150 4th St SW, Apt 1010, Washington, DC 20024
# 1150 4Th St Sw, Washington, Dc 20024
#
# 18179 Webster Rd APT 107, Gladstone, OR 97027
# 18179 Webster Rd Gladstone, Or 97027
#
# 8003 Woodway Dr, apt42, Houston, TX 77063
# 8003 Woodway Dr, Houston, Tx 77063
#
# 220 East Marshall Street, Apt. 22, Harrisonburg, VA 22801
# 220 East Marshall Street, Harrisonburg, Va 22801
#
# 65 Calumet St, Apt 2, Roxbury Crossing, MA 02120
# 65 Calumet St, Roxbury Crossing, Ma 02120
#
# 7725 GATEWAY UNIT 2569, Irvine, CA 92618
# 7725 Gateway Irvine, Ca 92618
#
# 110 West Grant St, Apt 14D, Minneapolis, MN 55403
# 110 West Grant St, Minneapolis, Mn 55403
#
# 4001 potter st., apt 59, Eugene, OR 97405
# 4001 Potter St., Eugene, Or 97405
#
# 3680 Beacon Avenue, Apt 120, Fremont, CA 94538
# 3680 Beacon Avenue, Fremont, Ca 94538
#
# 1030 Chester Rd, Apt 15, Lansing, MI 48912-4836
# 1030 Chester Rd, Lansing, Mi 48912-4836
#
# 3175 Cauby Street, apt 309, San Diego, CA 92110
# 3175 Cauby Street, San Diego, Ca 92110
#
# 510 sterling drive apt. 104, Bellingham, WA 98226
# 510 Sterling Drive Bellingham, Wa 98226
#
# 504 S Rawlings st, Apt 104, Carbondale, IL 62901
# 504 S Rawlings St, Carbondale, Il 62901
#
# 4609 Bancroft Street Apt 1, San Diego, CA 92116
# 4609 Bancroft Street San Diego, Ca 92116
#
# 310 S 4th st unit 1106, Phoenix, AZ 85004
# 310 S 4Th St Phoenix, Az 85004
#
# 3334 w. Dickens Ave. apt 2, Chicago, IL 60647
# 3334 W. Dickens Ave. Chicago, Il 60647
#
# 1600 Kickingbird Rd Apt, Edmond, OK 73034
# 1600 Kickingbird Rd Ok 73034
#
# 1635 Cook St. Apt. 104, Denver, CO 80206
# 1635 Cook St. Denver, Co 80206
#
# 345 Clark Dr, Apt 322, Coralville, IA 52241
# 345 Clark Dr, Coralville, Ia 52241
#
# 11 Main St S, Apt 315, Kirkland, WA 98033
# 11 Main St S, Kirkland, Wa 98033
#
# 6858 BEN AVE APT 4, N, CA 91605-6903
# 6858 Ben Ave N, Ca 91605-6903
#
# Room 418 Zonario apt 1001 W StMary rd, Tucson, AZ 85745
# Room 418 Zonario Tucson, Az 85745
#
# 11 SOMERS ST APT 1, Brooklyn, NY 11233
# 11 Somers St Brooklyn, Ny 11233
#
# 9525 Blake ln, APT 204, Fairfax, VA 22031
# 9525 Blake Ln, Fairfax, Va 22031
#
# 150, Melrose Ave E Apt 105, Seattle, WA 98102
# 150, Melrose Ave E Seattle, Wa 98102
#
# 6134 WOODMAN AVE APT 102, Van Nuys, CA 91401
# 6134 Woodman Ave Van Nuys, Ca 91401
#
# 2632 N Prospect Ave, Apt F, Milwaukee, WI 53211
# 2632 N Prospect Ave, Milwaukee, Wi 53211
#
# 50 South Boulder Circle Apt 5025 , Boulder, CO 80303
# 50 South Boulder Circle Boulder, Co 80303
#
# 84 Mariner St., Apt. 7, Buffalo, NY 14201
# 84 Mariner St., Buffalo, Ny 14201
#
# Embassy Towers 2625 Park Ave, Apt 1-S Bridgeport CT 06604, Apt 1-S, Bridgeport, CT 06604
# Embassy Towers 2625 Park Ave, Apt 1-S, Bridgeport, Ct 06604
#
# 2608 nw 59th st apt 1, Seattle, WA 98107
# 2608 Nw 59Th St Seattle, Wa 98107
#
# 785 Dekalb Ave, apt 1F, Brooklyn, NY 11221
# 785 Dekalb Ave, Brooklyn, Ny 11221
#
# 1100 Helen Drive, Unit 203, Newark, DE 19702
# 1100 Helen Drive, Newark, De 19702
#
# 1701 1st ave south apt 502, Birmingham, AL 35233
# 1701 1St Ave South Birmingham, Al 35233
#
# 12 E 64th ST APT 4, Savannah, GA 31405
# 12 E 64Th St Savannah, Ga 31405
#
# 1250 Skipper Rd Apt 111, Tampa, FL 33613
# 1250 Skipper Rd Tampa, Fl 33613
#
# 111 West Davis Street, Apt #2515, Dallas, TX 75208
# 111 West Davis Street, Dallas, Tx 75208
#
# 1250 Skipper Rd Apt 111, Tampa, FL 33613
# 1250 Skipper Rd Tampa, Fl 33613
#
# 565 Columbus Ave., Apt. 3a, Boston, MA 02118
# 565 Columbus Ave., Boston, Ma 02118
#
# 933 Willowleaf Dr Apt 602, San Jose, CA 95128
# 933 Willowleaf Dr San Jose, Ca 95128
#
# 933 Willowleaf Dr Apt 602, San Jose, CA 95128
# 933 Willowleaf Dr San Jose, Ca 95128
#
# 4435 piedmont ave unit 404, Oakland, CA 94611
# 4435 Piedmont Ave Oakland, Ca 94611
#
# 2827 14th Ave. W, Apt. 4, Seattle, WA 98119
# 2827 14Th Ave. W, Seattle, Wa 98119
#
# 4900 S Rio Grande Av, Apt 18A, Orlando, FL 32839-2326
# 4900 S Rio Grande Av, Orlando, Fl 32839-2326
#
# 3835 Baldwin Ave, apt 65, Lincoln, NE 68504
# 3835 Baldwin Ave, Lincoln, Ne 68504
#
# 2651 NW Thurman st., Apt 304, Portland, OR 97210
# 2651 Nw Thurman St., Portland, Or 97210
#
# 690 32nd St. Apt. 203, Bellingham, WA 98225
# 690 32Nd St. Bellingham, Wa 98225
#
# 5955 E 10th Ave Apt 101, Denver, CO 80220
# 5955 E 10Th Ave Denver, Co 80220
#
# 2700 E Cherry Creek South Dr, Apt 219, Denver, CO 80209
# 2700 E Cherry Creek South Dr, Denver, Co 80209
#
# 2700 E Cherry Creek South Dr Apt 219, Denver, CO 80209
# 2700 E Cherry Creek South Dr Denver, Co 80209
#
# 5224 SE 72nd Ave, Apt 58, Portland, OR 97206
# 5224 Se 72Nd Ave, Portland, Or 97206
#
# 2210 Sherman Avenue Apt L0, Evanston, IL 60201
# 2210 Sherman Avenue Evanston, Il 60201
#
# 1770 S. Williams St. , Apt. 401-S, Denver, CO 80210
# 1770 S. Williams St. , Denver, Co 80210
#
# 2625 S. Santa Fe Dr., Unit 1A, Denver, CO 80223
# 2625 S. Santa Fe Dr., Denver, Co 80223
#
# 404 Sturdy Rd., Apt A9, Valparaiso, IN 46383
# 404 Sturdy Rd., Valparaiso, In 46383
#
# 536 14th ST APT 1, San Francisco, CA 94103
# 536 14Th St San Francisco, Ca 94103
#
# 1240 Barton Hills Dr, Apt 122, Austin, TX 78704
# 1240 Barton Hills Dr, Austin, Tx 78704
#
# 363 W Charleston St Apt 533, Lincoln, NE 68528
# 363 W Charleston St Lincoln, Ne 68528
#
# 8400 Jamestown Dr, Apt 506, Austin, TX 78758
# 8400 Jamestown Dr, Austin, Tx 78758
#
# 6334 Rainier Ave S, Apt. 110, Seattle, WA 98122
# 6334 Rainier Ave S, Seattle, Wa 98122
#
# 5560 Lexington Ave, Apt 261, San Jose, CA 95123
# 5560 Lexington Ave, San Jose, Ca 95123
#
# 801 Moro St Apt 5, Manhattan, KS 66502
# 801 Moro St Manhattan, Ks 66502
#
# 855 BRANNAN STREET UNIT 571, San Francisco, CA 94103
# 855 Brannan Street San Francisco, Ca 94103
#
# 2629 Meade Avenue, Apt. B, San Diego, CA 92116
# 2629 Meade Avenue, San Diego, Ca 92116
#
# 8162 Richmond Ave. Apt.1211, Houston, TX 77063
# 8162 Richmond Ave. Houston, Tx 77063
#
# 8162 Richmond Ave. Apt.1211, Houston, TX 77063
# 8162 Richmond Ave. Houston, Tx 77063
#
# 549 fell street apt 8, San Francisco, CA 94102
# 549 Fell Street San Francisco, Ca 94102
#
# New York, United States, NY 10002
# New York, Ny 10002
#
# 4055 9th Ave NE Apt 201, Seattle, WA 98105
# 4055 9Th Ave Ne Seattle, Wa 98105
#
# 1537 NW 56th St, Unit 214, Seattle, WA 98107
# 1537 Nw 56Th St, Seattle, Wa 98107
#
# 9102 Bryant Ct (APT3A), Indianapolis, IN 46250
# 9102 Bryant Ct  Indianapolis, In 46250
#
# 1115 17th Ave, APT 301, Seattle, WA 98122
# 1115 17Th Ave, Seattle, Wa 98122
#
# 2400 E 6th St, apt 202, Austin, TX 78702
# 2400 E 6Th St, Austin, Tx 78702
#
# 301 W Stassney Ln, Unit 1, Austin, TX 78745
# 301 W Stassney Ln, Austin, Tx 78745
#
# 260 Springdale Street Apt. 23, Athens, GA 30606
# 260 Springdale Street Athens, Ga 30606
#
# 4245 Cortona Cove Unit 207, Oviedo, FL 32765
# 4245 Cortona Cove Oviedo, Fl 32765
#
# 1280 NW MADRAS HIGHWAY UNIT 12, Prineville, OR 97754
# 1280 Nw Madras Highway Prineville, Or 97754
#
# 1108 N Milwaukee St. Unit 119, Milwaukee, WI 53202
# 1108 N Milwaukee St. Milwaukee, Wi 53202
#
# 1734 6th Street Northwest, Unit 2, Washington, DC 20001
# 1734 6Th Street Northwest, Washington, Dc 20001
#
# 1017 PEARL STREET, UNIT A, Santa Monica, CA 90405
# 1017 Pearl Street, Santa Monica, Ca 90405
#
# 4747 30th Ave NE unit H156 , Seattle, WA 98105
# 4747 30Th Ave Ne Seattle, Wa 98105
#
# 3803 South Edmunds Street APT#25, Seattle, WA 98118
# 3803 South Edmunds Street Seattle, Wa 98118
#
# 4145 Shadow Lane apt 625, Santa Rosa, CA 95405
# 4145 Shadow Lane Santa Rosa, Ca 95405
#
# 8585 spice wood springs road apt 211 , Austin, TX 78759
# 8585 Spice Wood Springs Road Austin, Tx 78759
#
# 10489 Monte Vista Ave Montclair, CA 91763 United States, Montclair, CA 91763
# 10489 Monte Vista Ave Montclair, Ca 91763 Montclair, Ca 91763
#
# 915 Saint Paul St, Apt 1F, Baltimore, MD 21202
# 915 Saint Paul St, Baltimore, Md 21202
#
# 2800 Aurora Ave Unit 200, Boulder, CO 80303
# 2800 Aurora Ave Boulder, Co 80303
#
# 9567 Cedarhurst Ln Unit A, Highlands Ranch, CO 80129
# 9567 Cedarhurst Ln Highlands Ranch, Co 80129
#
# 3833 N. Fairview Ave. Unit 15, Tucson, AZ 85705
# 3833 N. Fairview Ave. Tucson, Az 85705
#
# 123 Queen Anne Ave N APT 204, Seattle, WA 98109
# 123 Queen Anne Ave N Seattle, Wa 98109
#
# 207 Gough St Apt 57, San Francisco, CA 94102
# 207 Gough St San Francisco, Ca 94102
#
# 290east truman Ave. Apt.#7, Salt Lake City, UT 84115
# 290East Truman Ave. Salt Lake City, Ut 84115
#
# Atlas Condo Bldg 3650 5th Ave unit 412, San Diego, CA 92103
# Atlas Condo Bldg 3650 5Th Ave San Diego, Ca 92103
#
# 1 E Scott St, Apt 2008, Chicago, IL 60610
# 1 E Scott St, Chicago, Il 60610
#
# 146 EVERIT ST APT E, New Haven, CT 06511-1345
# 146 Everit St New Haven, Ct 06511-1345
#
# 1101 17th Ave Apt 204, Seattle, WA 98122
# 1101 17Th Ave Seattle, Wa 98122
#
# 666 W Olympic Pl Apt 402, Seattle, WA 98119
# 666 W Olympic Pl Seattle, Wa 98119
#
# 15436 Lakeshore Boulevard, Apt 3, Cleveland, OH 44110
# 15436 Lakeshore Boulevard, Cleveland, Oh 44110
#
# 2390 SE Hawthorne, Apt 320, Portland, OR 97214
# 2390 Se Hawthorne, Portland, Or 97214
#
# Trillium Woods Apt Complex, Beaverton, OR 97007
# Trillium Woods Beaverton, Or 97007
#
# 825 N 4th St, APT 317, Columbus, OH 43215
# 825 N 4Th St, Columbus, Oh 43215
#
# 1325 North Highland Avenue. Apt#15, Clearwater, FL 33755
# 1325 North Highland Avenue. Clearwater, Fl 33755
#
# 1325 North Highland Avenue. Apt#15, Clearwater, FL 33755
# 1325 North Highland Avenue. Clearwater, Fl 33755
#
# 1235 wildwood Ave, APT 225, Sunnyvale, CA 94089
# 1235 Wildwood Ave, Sunnyvale, Ca 94089
#
# 962 e 500 s, apt b, Salt Lake City, UT 84102
# 962 E 500 S, Salt Lake City, Ut 84102
#
# 137 W CENTRAL AVE. UNIT B, Monrovia, CA 91016
# 137 W Central Ave. Monrovia, Ca 91016
#
# 90 Myrtle Street, Apt 6, Boston, MA 02114
# 90 Myrtle Street, Boston, Ma 02114
#
# 299 W. Washington Ave, Apt 421, Sunnyvale, CA 94086
# 299 W. Washington Ave, Sunnyvale, Ca 94086
#
# 1520 MockingBird Ln., Apt. 568, Charlotte, NC 28209
# 1520 Mockingbird Ln., Charlotte, Nc 28209
#
# 108 S COURTHOUSE RD APT 2164, Arlington, VA 22204
# 108 S Courthouse Rd Arlington, Va 22204
#
# 57 College Ave NE, Apt 1, Grand Rapids, MI 49503
# 57 College Ave Ne, Grand Rapids, Mi 49503
#
# 350 11th Ave unit 924, San Diego, CA 92101
# 350 11Th Ave San Diego, Ca 92101
#
# 23 Elm Street, Apt 101, Somerville, MA 02143
# 23 Elm Street, Somerville, Ma 02143
#
# 720 Ralph McGill Blvd APT103, Atlanta, GA 30312
# 720 Ralph Mcgill Blvd Atlanta, Ga 30312
#
# 1282 Lendrum Court Apt B, San Francisco, CA 94129
# 1282 Lendrum Court San Francisco, Ca 94129
#
# 126 N Berger Pkwy, Apt D4, Fond Du Lac, WI 54935-3070
# 126 N Berger Pkwy, Fond Du Lac, Wi 54935-3070
#
# 13725 32nd AVE NE APT B118, Seattle, WA 98125
# 13725 32Nd Ave Ne Seattle, Wa 98125
#
# 3415 Pierce Street Apt 101, San Francisco, CA 94123
# 3415 Pierce Street San Francisco, Ca 94123
#
# 500 N. 21st Street, Apt 820, Philadelphia, PA 19130
# 500 N. 21St Street, Philadelphia, Pa 19130
#
# 2276 Washington Blvd Apt 403, Ogden, UT 84401
# 2276 Washington Blvd Ogden, Ut 84401
#
# 721 Depew street Apt4 , Lakewood, CO 80214
# 721 Depew Street Lakewood, Co 80214
#
# 1310 5TH AVE, APT 2, San Francisco, CA 94122
# 1310 5Th Ave, San Francisco, Ca 94122
#
# 2405 ave n apt #A, Lubbock, TX 79411
# 2405 Ave N Lubbock, Tx 79411
#
# 205 Red Oak Dr W, Unit J, Sunnyvale, CA 94086
# 205 Red Oak Dr W, Sunnyvale, Ca 94086
#
# 915 Dempster Street, apt 2w, Evanston, IL 60201
# 915 Dempster Street, Evanston, Il 60201
#
# 4101 e Belleview st unit B, Phoenix, AZ 85008
# 4101 E Belleview St Phoenix, Az 85008
#
# 1202 Lakeview Blvd E Apt. 1, Seattle, WA 98102
# 1202 Lakeview Blvd E Seattle, Wa 98102
#
# 1031 Crestview Drive, Apt, Mountain View, CA 94040
# 1031 Crestview Drive, Ca 94040
#
# 3400 25th Ave W Apt 302, Seattle, WA 98199
# 3400 25Th Ave W Seattle, Wa 98199
#
# 220 Johnson St. Apt. 17B, Fall River, MA 02723
# 220 Johnson St. Fall River, Ma 02723
#
# 900 E 9th St Apt 4, Muscatine, IA 52761
# 900 E 9Th St Muscatine, Ia 52761
#
# 462 2nd Ave Apt. 2, San Francisco, CA 94118
# 462 2Nd Ave San Francisco, Ca 94118
#
# 2700 Colorado Blvd Unit 14, Denton, TX 76210
# 2700 Colorado Blvd Denton, Tx 76210
#
# 845 Ramona ST APT 625, Palo Alto, CA 94301
# 845 Ramona St Palo Alto, Ca 94301
#
# 1485 tchoupitulas st Unit 11218, New Orleans, LA 70130
# 1485 Tchoupitulas St New Orleans, La 70130
# Apartments with the prefix #_____
# ---------------------
#
# 2170 6th Avenue N, #201, Seattle, WA 98109
# 2170 6Th Avenue N,  Seattle, Wa 98109
#
# 3272 Fuhrman Ave E #218, Seattle, WA 98102
# 3272 Fuhrman Ave E  Seattle, Wa 98102
#
# 142 santa lucia ave #5, San Bruno, CA 94066
# 142 Santa Lucia Ave  San Bruno, Ca 94066
#
# 5211 Pacific Concourse Dr #1431 Los Angeles , Los Angels, CA 90045
# 5211 Pacific Concourse Dr  Los Angels, Ca 90045
#
# 5211 Pacific Concourse Dr #1431 Los Angeles , Los Angles, CA 90045
# 5211 Pacific Concourse Dr  Los Angles, Ca 90045
#
# 825 E Evelyn #624, Sunnyvale, CA 94086
# 825 E Evelyn  Sunnyvale, Ca 94086
#
# 12726 se division st #29, Portland, OR 97236
# 12726 Se Division St  Portland, Or 97236
#
# 22 n spruce st, #204, Colorado Springs, CO 80905
# 22 N Spruce St,  Colorado Springs, Co 80905
#
# 1900 Westlake Ave N #B3, Seattle, WA 98109
# 1900 Westlake Ave N  Seattle, Wa 98109
#
# 2005 w 14th Street #100, Tempe, AZ 85281
# 2005 W 14Th Street  Tempe, Az 85281
#
# 4257 N. Alaska street, #119, Portland, OR 97203
# 4257 N. Alaska Street,  Portland, Or 97203
#
# 22985 climbing rose dr #206 , Moreno Valley, CA 92557
# 22985 Climbing Rose Dr  Moreno Valley, Ca 92557
#
# 2200 Montopolis Dr #1111, Austin, TX 78741
# 2200 Montopolis Dr  Austin, Tx 78741
#
# 11101 Ulmerton Rd Largo, FL 33778 Store #1701, Largo, FL 33778
# 11101 Ulmerton Rd Largo, Fl 33778 Store  Largo, Fl 33778
#
# 838 NE 66th St #111, , Seattle, WA 98115
# 838 Ne 66Th St  , Seattle, Wa 98115
#
# 49 N 400 W #201, Provo, UT 84601
# 49 N 400 W  Provo, Ut 84601
#
# 325 S College Ave #4029, Indianapolis, IN 46204
# 325 S College Ave  Indianapolis, In 46204
#
# 25 Heritage Halls, #3102, Provo, UT 84602
# 25 Heritage Halls,  Provo, Ut 84602
#
# 71 Curtner Ave #80, San Jose, CA 95125
# 71 Curtner Ave  San Jose, Ca 95125
#
# Caltrain #232 Departing Sf At 8:45am, Arriving San Jose 10:11am, CA 94110
# Caltrain  Arriving San Jose 10:11Am, Ca 94110
#
# 2211 West North Loop Blvd., #235, Austin, TX 78756
# 2211 West North Loop Blvd.,  Austin, Tx 78756
#
# 157 Ramsdell Ave #3, Buffalo, NY 14216
# 157 Ramsdell Ave  Buffalo, Ny 14216
#
# 2032 Belmont Rd NW, #522, Washington, DC 20009
# 2032 Belmont Rd Nw,  Washington, Dc 20009
#
# 1408 Massachusetts Ave # 1414, Cambridge, MA 02138
# 1408 Massachusetts Ave  Cambridge, Ma 02138
#
# 500 bankside way #212, Sacramento, CA 95835
# 500 Bankside Way  Sacramento, Ca 95835
#
# 757 MACON ST # 3, Brooklyn, NY 11233
# 757 Macon St  Brooklyn, Ny 11233
#
# 111 E Oak St #1a, Bozeman, MT 59715
# 111 E Oak St  Bozeman, Mt 59715
#
# 1315 4th Ave #2503, Seattle, WA 98101
# 1315 4Th Ave  Seattle, Wa 98101
#
# 2039 e. Johnson St. #1, Madison, WI 53703
# 2039 E. Johnson St.  Madison, Wi 53703
#
# 1230 E. Spence Ave #2, Tempe, AZ 85281
# 1230 E. Spence Ave  Tempe, Az 85281
#
# 2727 Kings Rd, #1105, Dallas, TX 75219
# 2727 Kings Rd,  Dallas, Tx 75219
#
# 736 Marlin Avenue #3, Foster City, CA 94404
# 736 Marlin Avenue  Foster City, Ca 94404
#
# 8801 St. Thomas Drive, #81, Pasco, WA 99301
# 8801 St. Thomas Drive,  Pasco, Wa 99301
#
# 3577 s Kingsburg Cv#22, Magna, UT 84044
# 3577 S Kingsburg Cv Magna, Ut 84044
#
# 1475 NW 92nd st, #7, Seattle, WA 98117
# 1475 Nw 92Nd St,  Seattle, Wa 98117
#
#  3303 S Bond Ave #1, Portland, OR 97239
#  3303 S Bond Ave  Portland, Or 97239
#
# 2901 Ocean Park Blvd #118, Santa Monica, CA 90405
# 2901 Ocean Park Blvd  Santa Monica, Ca 90405
#
# 880 State Road 136 Ste. #1, Baraboo, WI 53913
# 880 State Road 136 Ste.  Baraboo, Wi 53913
#
# 2126 Isleta Blvd SW #C1, Albuquerque, NM 87105
# 2126 Isleta Blvd Sw  Albuquerque, Nm 87105
#
# 110 6th Ave # 3, Lake, San Francisco, CA 94118
# 110 6Th Ave  Lake, San Francisco, Ca 94118
#
# 1600 28th St #1200, Boulder, CO 80301
# 1600 28Th St  Boulder, Co 80301
#
# 2901 s 26th place #1328, Rogers, AR 72758
# 2901 S 26Th Place  Rogers, Ar 72758
#
# 25 KEYSTONE AVE, # 10, Reno, NV 89503
# 25 Keystone Ave,  Reno, Nv 89503
#
# 130 W Maryland Ave #10, Phoenix, AZ 85013
# 130 W Maryland Ave  Phoenix, Az 85013
#
# 655 Goodpasture Island Rd, #37, Eugene, OR 97401
# 655 Goodpasture Island Rd,  Eugene, Or 97401
#
# 700 Broadway E #112, Seattle, WA 98102
# 700 Broadway E  Seattle, Wa 98102
#
# 12411 East 8th Ave. #22, Spokane, WA 99206
# 12411 East 8Th Ave.  Spokane, Wa 99206
#
# #6, CA 94103
#  Ca 94103
#
# 525 West 2nd #20, Reno, NV 89503
# 525 West 2Nd  Reno, Nv 89503
#
# 475 W San Carlos Street, # 5103, San Jose, CA 95110
# 475 W San Carlos Street,  San Jose, Ca 95110
#
# 533 S Western Ave #B, Los Angeles, CA 90020
# 533 S Western Ave  Los Angeles, Ca 90020
#
# 165 blossom Hill rd. #222, San Jose, CA 95123
# 165 Blossom Hill Rd.  San Jose, Ca 95123
#
# 358 Blue River Pkwy #H, Silverthorne, CO 80498
# 358 Blue River Pkwy  Silverthorne, Co 80498
#
# 2121 SE Belmont St, #130, Portland, OR 97214
# 2121 Se Belmont St,  Portland, Or 97214
#
# 870 E El Camino Real #97, Mountain View, CA 94040
# 870 E El Camino Real  Mountain View, Ca 94040
#
# 10655 Lemon Ave #1804, Rancho Cucamonga, CA 91737
# 10655 Lemon Ave  Rancho Cucamonga, Ca 91737
#
#
# Apartments with format , #### ,
# ---------------------
#
# 3477 Lily Way, 107, San Jose, CA 95134
# 3477 Lily Way San Jose, Ca 95134
#
# 3054 West Wilson Avenue, 2, Chicago, IL 60625
# 3054 West Wilson Avenue Chicago, Il 60625
#
# 151 Southeast 1st Street, 2004, Miami, FL 33131
# 151 Southeast 1St Street Miami, Fl 33131
#
# 2550 E River Rd, 14203, Tucson, AZ 85718
# 2550 E River Rd Tucson, Az 85718
#
# 2550 E River Rd, 14203, Tucson, AZ 85718
# 2550 E River Rd Tucson, Az 85718
#
# 815 HARBOR CLIFF WAY, 252, Oceanside, CA 92054
# 815 Harbor Cliff Way Oceanside, Ca 92054
#
# 2502 NE Broadway St, , Portland, OR 97232
# 2502 Ne Broadway St Portland, Or 97232
#
# 9207 Bolton Ave, , Hudson, FL 34667
# 9207 Bolton Ave Hudson, Fl 34667
#
# 240 N Bayshore blvd, 213, San Mateo, NC 94401
# 240 N Bayshore Blvd San Mateo, Nc 94401
#
# 1625w Olympic Blvd Ste, 701, 31, Los Angeles, CA 90013
# 1625W Olympic Blvd Ste 31, Los Angeles, Ca 90013
#
# 625 8th St, , San Francisco, CA 94103
# 625 8Th St San Francisco, Ca 94103
#
# 625 8th St, , San Francisco, CA 94103
# 625 8Th St San Francisco, Ca 94103
#
# 6143 Orange St, 2, Los Angeles, CA 90048
# 6143 Orange St Los Angeles, Ca 90048
#
# 6901 Prairie Road NE, 203, Albuquerque, NM 87109
# 6901 Prairie Road Ne Albuquerque, Nm 87109
#
# 9030 Southwestern Blvd, 3114, Dallas, TX 75214
# 9030 Southwestern Blvd Dallas, Tx 75214
#
# 5604 Southwest Parkway, 2122, Austin, TX 78735
# 5604 Southwest Parkway Austin, Tx 78735
#
# 18011 Newhope St G, , Fountain Valley, CA 92708
# 18011 Newhope St G Fountain Valley, Ca 92708
#
# Luna Apartments, 6921 Roosevelt Way Ne, 98115, WA Seattle
# Luna Apartments, 6921 Roosevelt Way Ne Wa Seattle
#
# 1006 W. Lake St, 321, Minneapolis, MN 55408
# 1006 W. Lake St Minneapolis, Mn 55408
#
# 3855 Iroquois St, , Detroit, MI 48214
# 3855 Iroquois St Detroit, Mi 48214
#
# 4200 N Pennsylvania Ave, , Oklahoma City,, OK 73112
# 4200 N Pennsylvania Ave Oklahoma City,, Ok 73112
#
# 346 CONNECTICUT ST, 202, Buffalo, NY 14213
# 346 Connecticut St Buffalo, Ny 14213
#
# 1 Dr Carlton B Goodlett Pl, , San Francisco, CA 94102
# 1 Dr Carlton B Goodlett Pl San Francisco, Ca 94102
#
# Seattle, 98107, WA 98107
# Seattle Wa 98107
#
# 7178 N Jackson Ave. , 103, Fresno, CA 93720
# 7178 N Jackson Ave.  Fresno, Ca 93720
#
# 11860 CHANDLER BLVD, 17, Valley, CA 91607
# 11860 Chandler Blvd Valley, Ca 91607
#
# 111 Powell St, , San Francisco, CA 94102
# 111 Powell St San Francisco, Ca 94102
#
# 529 Flat Shoals Ave SE, , Atlanta, GA 30316
# 529 Flat Shoals Ave Se Atlanta, Ga 30316
#
# Indianapolis, 46205, IN
# Indianapolis In
#
# Portland, Or, 97206, OR
# Portland, Or Or
#
# 441 Meeting Str, 328, Charleston, SC 29403
# 441 Meeting Str Charleston, Sc 29403
#
# 188 Avenue A, NY, 10009, New York, NY 10009
# 188 Avenue A, Ny New York, Ny 10009
#
# 395 Columbia Street, 1/2, Cambridge, MA 02141
# 395 Columbia Street Cambridge, Ma 02141
#
# 5525 Cedar Lake Rd S, , St. Louis Park, MN 55416
# 5525 Cedar Lake Rd S St. Louis Park, Mn 55416
#
# 5055 S. Dorchester Ave., 101, Chicago, IL 60615
# 5055 S. Dorchester Ave. Chicago, Il 60615
#
#
# Apartments with the word Ste (studio/suite)
# ---------------------
#
# 3001 Hennepin Ave w Ste 2210, Minneapolis, MN 55408-3520
# 3001 Hennepin Ave W Minneapolis, Mn 55408-3520
#
# 2920 Geneva CT STE 202, Denver, CO 80238
# 2920 Geneva Ct Denver, Co 80238
#
# 110 Stony Point Rd., Ste. 105, Santa Rosa, CA 95401
# 110 Stony Point Rd., Santa Rosa, Ca 95401
#
# 905 NE 45th St, Ste B, Seattle, WA 98105
# 905 Ne 45Th St, Seattle, Wa 98105
#
# 65 Division Ave Ste M, Eugene, OR 97404
# 65 Division Ave Eugene, Or 97404
#
#
# Addresses with Directional Abbreviations
# ---------------------
#
# 1948 NW Blue Ridge Dr, Seattle, WA 98177
# 1948 NorthWest Blue Ridge Dr, Seattle, Wa 98177
# 1948 Blue Ridge Dr, Seattle, Wa 98177
#
# 747 W Cornelia , Chicago, IL 60657
# 747 West Cornelia , Chicago, Il 60657
# 747 Cornelia , Chicago, Il 60657
#
# 3001 Hennepin Ave W Minneapolis, Mn 55408-3520
# 3001 Hennepin Ave West Minneapolis, Mn 55408-3520
# 3001 Hennepin Ave Minneapolis, Mn 55408-3520
#
# 4789 N Amherst St , Portland, OR 97203
# 4789 North Amherst St , Portland, Or 97203
# 4789 Amherst St , Portland, Or 97203
#
# 808 W San Carlos Street, San Jose, CA 95126
# 808 West San Carlos Street, San Jose, Ca 95126
# 808 San Carlos Street, San Jose, Ca 95126
#
# 1071 W Martin Luther King Jr Blvd, Los Angeles, CA 90007
# 1071 West Martin Luther King Jr Blvd, Los Angeles, Ca 90007
# 1071 Martin Luther King Jr Blvd, Los Angeles, Ca 90007
#
# 901 W 50th Street, North Little Rock, AR 72118
# 901 West 50Th Street, North Little Rock, Ar 72118
# 901 50Th Street, North Little Rock, Ar 72118
#
# 1030 E Green St, Pasadena, CA 91106
# 1030 East Green St, Pasadena, Ca 91106
# 1030 Green St, Pasadena, Ca 91106
#
# 2566 S Kinnickinnic Ave, Milwaukee, WI 53207
# 2566 South Kinnickinnic Ave, Milwaukee, Wi 53207
# 2566 Kinnickinnic Ave, Milwaukee, Wi 53207
#
# 2140 Nw Kearney St Portland, Or 97210
# 2140 NorthWest Kearney St Portland, Or 97210
# 2140 Kearney St Portland, Or 97210
#
# 34828 SE Douglas St, Snoqualmie, WA 98065
# 34828 SouthEast Douglas St, Snoqualmie, Wa 98065
# 34828 Douglas St, Snoqualmie, Wa 98065
#
# 650 E Bidwell, Folsom, CA 95630
# 650 East Bidwell, Folsom, Ca 95630
# 650 Bidwell, Folsom, Ca 95630
#
# 3272 Fuhrman Ave E  Seattle, Wa 98102
# 3272 Fuhrman Ave East  Seattle, Wa 98102
# 3272 Fuhrman Ave  Seattle, Wa 98102
#
# 1959 NE Pacific St, Seattle, WA
# 1959 NorthEast Pacific St, Seattle, Wa
# 1959 Pacific St, Seattle, Wa
#
# Corner of K st NW and Vermont from rack in front of Pret a Manger, Washington, DC 20002
# Corner Of K St NorthWest And Vermont From Rack In Front Of Pret A Manger, Washington, Dc 20002
# Corner Of K St And Vermont From Rack In Front Of Pret A Manger, Washington, Dc 20002
#
# 111 SW Columbia Street, Portland, OR 97201
# 111 SouthWest Columbia Street, Portland, Or 97201
# 111 Columbia Street, Portland, Or 97201
#
# 501 NE Stafford Street, Portland, OR 97211
# 501 NorthEast Stafford Street, Portland, Or 97211
# 501 Stafford Street, Portland, Or 97211
#
# 1001 16th St NW & K St, Washington, DC 20036
# 1001 16Th St NorthWest & K St, Washington, Dc 20036
# 1001 16Th St & K St, Washington, Dc 20036
#
# 3850 N Mississippi Ave, Portland, OR 97227
# 3850 North Mississippi Ave, Portland, Or 97227
# 3850 Mississippi Ave, Portland, Or 97227
#
# 800 N 3rd St, Minneapolis, MN 55401
# 800 North 3Rd St, Minneapolis, Mn 55401
# 800 3Rd St, Minneapolis, Mn 55401
#
# 131 NE MLK JR., Portland, OR 97232
# 131 NorthEast Mlk Jr., Portland, Or 97232
# 131 Mlk Jr., Portland, Or 97232
#
# 424 E 36th St, Charlotte, NC 28205
# 424 East 36Th St, Charlotte, Nc 28205
# 424 36Th St, Charlotte, Nc 28205
#
# 1033 S 33rd St , Omaha, NE 68105
# 1033 South 33Rd St , Omaha, Ne 68105
# 1033 33Rd St , Omaha, Ne 68105
#
# 100 W Broadway, Glendale, CA 91210
# 100 West Broadway, Glendale, Ca 91210
# 100 Broadway, Glendale, Ca 91210
#
# 9401 SE 82nd Ave, Portland, OR 97086
# 9401 SouthEast 82Nd Ave, Portland, Or 97086
# 9401 82Nd Ave, Portland, Or 97086
#
# 10851 W Montfair Blvd, The Woodlands, TX 77382
# 10851 West Montfair Blvd, The Woodlands, Tx 77382
# 10851 Montfair Blvd, The Woodlands, Tx 77382
#
# 800 n 3rd st, Minneapolis, MN 55401
# 800 North 3Rd St, Minneapolis, Mn 55401
# 800 3Rd St, Minneapolis, Mn 55401
#
# 1830 NW 24th Pl., Portland, OR 97210
# 1830 NorthWest 24Th Pl., Portland, Or 97210
# 1830 24Th Pl., Portland, Or 97210
#
# 11 W Aloha St. RM, Seattle, WA 98119
# 11 West Aloha St. Rm, Seattle, Wa 98119
# 11 Aloha St. Rm, Seattle, Wa 98119
#
# Paul Allen Center, 185 E Stevens Way NE AE100R, Seattle, WA 98195
# Paul Allen Center, 185 East Stevens Way Ne Ae100R, Seattle, Wa 98195
# Paul Allen Center, 185 Stevens Way Ne Ae100R, Seattle, Wa 98195
#
# 1220 S Lincoln Ave, Boise, ID 83706
# 1220 South Lincoln Ave, Boise, Id 83706
# 1220 Lincoln Ave, Boise, Id 83706
#
# 807 SW 14th Avenue, Portland, OR 97205
# 807 SouthWest 14Th Avenue, Portland, Or 97205
# 807 14Th Avenue, Portland, Or 97205
#
# 3600 W Broad St, Richmond, VA 23230
# 3600 West Broad St, Richmond, Va 23230
# 3600 Broad St, Richmond, Va 23230
#
# 321 S Pierce Street, New Orleans, LA 70115
# 321 South Pierce Street, New Orleans, La 70115
# 321 Pierce Street, New Orleans, La 70115
#
# 2202 W North Loop Blvd Austin, Tx 78756
# 2202 West North Loop Blvd Austin, Tx 78756
# 2202 North Loop Blvd Austin, Tx 78756
#
# 3911 N 13th Street, Tacoma, WA 98406
# 3911 North 13Th Street, Tacoma, Wa 98406
# 3911 13Th Street, Tacoma, Wa 98406
#
# 500 S Genois Street , New Orleans, LA 70119
# 500 South Genois Street , New Orleans, La 70119
# 500 Genois Street , New Orleans, La 70119
#
# 7270 W Manchester Avenue, Los Angeles, CA 90045
# 7270 West Manchester Avenue, Los Angeles, Ca 90045
# 7270 Manchester Avenue, Los Angeles, Ca 90045
#
# 339 SE 28th Ave, Portland, OR 97214
# 339 SouthEast 28Th Ave, Portland, Or 97214
# 339 28Th Ave, Portland, Or 97214
#
# 620 N 34th St , Seattle, WA 98103
# 620 North 34Th St , Seattle, Wa 98103
# 620 34Th St , Seattle, Wa 98103
#
# 7905A SE Powell Blvd, Portland, OR 97206
# 7905A SouthEast Powell Blvd, Portland, Or 97206
# 7905A Powell Blvd, Portland, Or 97206
#
# 4727 SE 86th Ct, Portland, OR 97266
# 4727 SouthEast 86Th Ct, Portland, Or 97266
# 4727 86Th Ct, Portland, Or 97266
#
# 612 NW 3rd St, Gainesville, FL 32601
# 612 NorthWest 3Rd St, Gainesville, Fl 32601
# 612 3Rd St, Gainesville, Fl 32601
#
# 1401 S 10Th St Waco, Tx 76706
# 1401 South 10Th St Waco, Tx 76706
# 1401 10Th St Waco, Tx 76706
#
# 1050 NE Butler Market Rd, Bend, OR 97701
# 1050 NorthEast Butler Market Rd, Bend, Or 97701
# 1050 Butler Market Rd, Bend, Or 97701
#
# 4509 W 36th 1/2 St, Saint Louis Park, MN 55416
# 4509 West 36Th 1/2 St, Saint Louis Park, Mn 55416
# 4509 36Th 1/2 St, Saint Louis Park, Mn 55416
#
# N Warner and N 19th, Tacoma, WA 98406
# N Warner And North 19Th, Tacoma, Wa 98406
# N Warner And 19Th, Tacoma, Wa 98406
#
# 3702 W Valley Hwy N, Auburn, WA 98001
# 3702 West Valley Hwy N, Auburn, Wa 98001
# 3702 Valley Hwy N, Auburn, Wa 98001
#
# 2520 S 8Th St Minneapolis, Mn 55454
# 2520 South 8Th St Minneapolis, Mn 55454
# 2520 8Th St Minneapolis, Mn 55454
#
# 2380 S MacGregor Way, Houston, TX 77021
# 2380 South Macgregor Way, Houston, Tx 77021
# 2380 Macgregor Way, Houston, Tx 77021
#
# Omaha, NE 68106
# Omaha, NorthEast 68106
# Omaha, 68106
#
# 2634 N Stowell Ave, Milwaukee, WI 53211
# 2634 North Stowell Ave, Milwaukee, Wi 53211
# 2634 Stowell Ave, Milwaukee, Wi 53211
#
# 2634 N Stowell Ave, Milwaukee, WI 53211
# 2634 North Stowell Ave, Milwaukee, Wi 53211
# 2634 Stowell Ave, Milwaukee, Wi 53211
#
# 5249 NE 72nd Ave, Portland, OR 97218
# 5249 NorthEast 72Nd Ave, Portland, Or 97218
# 5249 72Nd Ave, Portland, Or 97218
#
# 916 E State St, Milwaukee, WI 53202
# 916 East State St, Milwaukee, Wi 53202
# 916 State St, Milwaukee, Wi 53202
#
# 309 n jefferson, Springfield, MO 65806
# 309 North Jefferson, Springfield, Mo 65806
# 309 Jefferson, Springfield, Mo 65806
#
# 2417 w 32nd ave, Denver, CO 80211
# 2417 West 32Nd Ave, Denver, Co 80211
# 2417 32Nd Ave, Denver, Co 80211
#
# 10270 NE 12th St., Bellevue, WA 98004
# 10270 NorthEast 12Th St., Bellevue, Wa 98004
# 10270 12Th St., Bellevue, Wa 98004
#
# 9118 W 50TH LN, Arvada, CO 80002-4431
# 9118 West 50Th Ln, Arvada, Co 80002-4431
# 9118 50Th Ln, Arvada, Co 80002-4431
#
# 18227 Bothell Way NE (Seattle Electric Bike), Bothell, WA 98011
# 18227 Bothell Way NorthEast (Seattle Electric Bike), Bothell, Wa 98011
# 18227 Bothell Way (Seattle Electric Bike), Bothell, Wa 98011
#
# 7548 N Silverbell Rd, Tucson, AZ 85741
# 7548 North Silverbell Rd, Tucson, Az 85741
# 7548 Silverbell Rd, Tucson, Az 85741
#
# 1206 S 4th Street, Ames, IA 50014
# 1206 South 4Th Street, Ames, Ia 50014
# 1206 4Th Street, Ames, Ia 50014
#
# N Cook St & N Mississippi Ave, Portland, OR
# N Cook St & North Mississippi Ave, Portland, Or
# N Cook St & Mississippi Ave, Portland, Or
#
# N Cook St & N Mississippi Ave, Portland, OR
# N Cook St & North Mississippi Ave, Portland, Or
# N Cook St & Mississippi Ave, Portland, Or
#
# 1741 NE 58th Ave, Portland, OR 97213-4101
# 1741 NorthEast 58Th Ave, Portland, Or 97213-4101
# 1741 58Th Ave, Portland, Or 97213-4101
#
# 1221 nw 126th Street, Seattle, WA 98177
# 1221 NorthWest 126Th Street, Seattle, Wa 98177
# 1221 126Th Street, Seattle, Wa 98177
#
# NW43rd st/ 9 Ave NW , Seattle, WA 98107
# Nw43Rd St/ 9 Ave NorthWest , Seattle, Wa 98107
# Nw43Rd St/ 9 Ave , Seattle, Wa 98107
#
# 5162 N Leavitt St, Chicago, IL 60625
# 5162 North Leavitt St, Chicago, Il 60625
# 5162 Leavitt St, Chicago, Il 60625
#
# 2348 N Harding Ave, Chicago, Il 60647
# 2348 North Harding Ave, Chicago, Il 60647
# 2348 Harding Ave, Chicago, Il 60647
#
# 3301 S Bear St, Santa Ana, CA 92704
# 3301 South Bear St, Santa Ana, Ca 92704
# 3301 Bear St, Santa Ana, Ca 92704
#
# 1221 S Gaffey St, San Pedro, CA 90731
# 1221 South Gaffey St, San Pedro, Ca 90731
# 1221 Gaffey St, San Pedro, Ca 90731
#
# 1320 W Lake St , Minneapolis, MN 55408
# 1320 West Lake St , Minneapolis, Mn 55408
# 1320 Lake St , Minneapolis, Mn 55408
#
# 825 E Evelyn  Sunnyvale, Ca 94086
# 825 East Evelyn  Sunnyvale, Ca 94086
# 825 Evelyn  Sunnyvale, Ca 94086
#
# 49 W 1st Ave , Denver, CO 80223
# 49 West 1St Ave , Denver, Co 80223
# 49 1St Ave , Denver, Co 80223
#
# 428 e Wendell Way, South Salt Lake, UT 84115
# 428 East Wendell Way, South Salt Lake, Ut 84115
# 428 Wendell Way, South Salt Lake, Ut 84115
#
# 5909 NE 34th Ave, Portland, OR 97211
# 5909 NorthEast 34Th Ave, Portland, Or 97211
# 5909 34Th Ave, Portland, Or 97211
#
# 8601 SE 17th Ave, Portland, OR
# 8601 SouthEast 17Th Ave, Portland, Or
# 8601 17Th Ave, Portland, Or
#
# 5429 E Mineral Cir, Centennial, CO 80122
# 5429 East Mineral Cir, Centennial, Co 80122
# 5429 Mineral Cir, Centennial, Co 80122
#
# 13701 NE 171st St, Woodinville, WA 98072
# 13701 NorthEast 171St St, Woodinville, Wa 98072
# 13701 171St St, Woodinville, Wa 98072
#
# 6956 N Wolcott ave , Chicago, IL 60626
# 6956 North Wolcott Ave , Chicago, Il 60626
# 6956 Wolcott Ave , Chicago, Il 60626
#
# 19523 Aurora Ave N Wa, Shoreline, Wa 98177
# 19523 Aurora Ave North Wa, Shoreline, Wa 98177
# 19523 Aurora Ave Wa, Shoreline, Wa 98177
#
# 2706 NE Mason St, Portland, OR 97211
# 2706 NorthEast Mason St, Portland, Or 97211
# 2706 Mason St, Portland, Or 97211
#
# 4504 W Spruce st, Tampa, FL FL
# 4504 West Spruce St, Tampa, Fl Fl
# 4504 Spruce St, Tampa, Fl Fl
#
# 3155 SW Moody Ave, Portland, OR 97239
# 3155 SouthWest Moody Ave, Portland, Or 97239
# 3155 Moody Ave, Portland, Or 97239
#
# 637 E Fountain Blvd, Colorado Springs, CO 80903
# 637 East Fountain Blvd, Colorado Springs, Co 80903
# 637 Fountain Blvd, Colorado Springs, Co 80903
#
# 1699 S Colorado Blvd, Denver, CO 80222
# 1699 South Colorado Blvd, Denver, Co 80222
# 1699 Colorado Blvd, Denver, Co 80222
#
# 1650 S State St, Salt Lake City, UT 84115
# 1650 South State St, Salt Lake City, Ut 84115
# 1650 State St, Salt Lake City, Ut 84115
#
# 1650 S State St, Salt Lake City, UT 84115
# 1650 South State St, Salt Lake City, Ut 84115
# 1650 State St, Salt Lake City, Ut 84115
#
# 732 Lamont St Nw Washington, Dc 20010
# 732 Lamont St NorthWest Washington, Dc 20010
# 732 Lamont St Washington, Dc 20010
#
# 970 N Dodge, Tucson, AZ 85711
# 970 North Dodge, Tucson, Az 85711
# 970 Dodge, Tucson, Az 85711
#
# Academy Apartments, Lincoln, NE 68508
# Academy Apartments, Lincoln, NorthEast 68508
# Academy Apartments, Lincoln, 68508
#
# 8338 NE Alderwood Rd. , Portland, OR 97220
# 8338 NorthEast Alderwood Rd. , Portland, Or 97220
# 8338 Alderwood Rd. , Portland, Or 97220
#
# 3155 SW Moody Ave, Portland, OR 97239
# 3155 SouthWest Moody Ave, Portland, Or 97239
# 3155 Moody Ave, Portland, Or 97239
#
# 1202 SW 1st Ave, Gainseville, FL 23601
# 1202 SouthWest 1St Ave, Gainseville, Fl 23601
# 1202 1St Ave, Gainseville, Fl 23601
#
# 6450 NE Radford Drive, Seattle, WA 98115
# 6450 NorthEast Radford Drive, Seattle, Wa 98115
# 6450 Radford Drive, Seattle, Wa 98115
#
# Omaha, NE 68106
# Omaha, NorthEast 68106
# Omaha, 68106
#
# 755 s spring st, Los Angeles, CA 90014
# 755 South Spring St, Los Angeles, Ca 90014
# 755 Spring St, Los Angeles, Ca 90014
#
# 2126 S Fairway AVE, Springfield, MO 65804
# 2126 South Fairway Ave, Springfield, Mo 65804
# 2126 Fairway Ave, Springfield, Mo 65804
#
# 3445 NE Williams, Portland, OR 97212
# 3445 NorthEast Williams, Portland, Or 97212
# 3445 Williams, Portland, Or 97212
#
# 226 W Laurel, Fort Collins, CO 80521
# 226 West Laurel, Fort Collins, Co 80521
# 226 Laurel, Fort Collins, Co 80521
#
# 7035 N Missouri Ave, Portland, OR 97210
# 7035 North Missouri Ave, Portland, Or 97210
# 7035 Missouri Ave, Portland, Or 97210
#
# 251 E 13th St, New York City, NY 10003
# 251 East 13Th St, New York City, Ny 10003
# 251 13Th St, New York City, Ny 10003
#
# 2550 E River Rd Tucson, Az 85718
# 2550 East River Rd Tucson, Az 85718
# 2550 River Rd Tucson, Az 85718
#
# 3445 NE Williams, Portland, OR 97212
# 3445 NorthEast Williams, Portland, Or 97212
# 3445 Williams, Portland, Or 97212
#
# 226 W Laurel, Fort Collins, CO 80521
# 226 West Laurel, Fort Collins, Co 80521
# 226 Laurel, Fort Collins, Co 80521
#
# 7035 N Missouri Ave, Portland, OR 97210
# 7035 North Missouri Ave, Portland, Or 97210
# 7035 Missouri Ave, Portland, Or 97210
#
# 251 E 13th St, New York City, NY 10003
# 251 East 13Th St, New York City, Ny 10003
# 251 13Th St, New York City, Ny 10003
#
# 2550 E River Rd Tucson, Az 85718
# 2550 East River Rd Tucson, Az 85718
# 2550 River Rd Tucson, Az 85718
#
# 7544 SE Monarch Lane, Hillsboro, OR 97123
# 7544 SouthEast Monarch Lane, Hillsboro, Or 97123
# 7544 Monarch Lane, Hillsboro, Or 97123
#
# 2126 S Fairway AVE, Springfield, MO 65804
# 2126 South Fairway Ave, Springfield, Mo 65804
# 2126 Fairway Ave, Springfield, Mo 65804
#
# 2900 E Ramon Road, Palm Springs, CA 92264
# 2900 East Ramon Road, Palm Springs, Ca 92264
# 2900 Ramon Road, Palm Springs, Ca 92264
#
# 77 NE Grand ave, Portland, OR 97232
# 77 NorthEast Grand Ave, Portland, Or 97232
# 77 Grand Ave, Portland, Or 97232
#
# 11650 W Pico Blvb, Los Angeles, CA 90064
# 11650 West Pico Blvb, Los Angeles, Ca 90064
# 11650 Pico Blvb, Los Angeles, Ca 90064
#
# 4666 Poppleton Ave, Omaha, NE 68106
# 4666 Poppleton Ave, Omaha, NorthEast 68106
# 4666 Poppleton Ave, Omaha, 68106
#
# 5858 S Riveridge Ln., Portland, OR 97239
# 5858 South Riveridge Ln., Portland, Or 97239
# 5858 Riveridge Ln., Portland, Or 97239
#
# 231 S 34th St, Philadelphia, PA 19104
# 231 South 34Th St, Philadelphia, Pa 19104
# 231 34Th St, Philadelphia, Pa 19104
#
# 1317 SE 8th St, Minneapolis, MN 55414
# 1317 SouthEast 8Th St, Minneapolis, Mn 55414
# 1317 8Th St, Minneapolis, Mn 55414
#
# 1218 w lunt, Chicago, IL 60626
# 1218 West Lunt, Chicago, Il 60626
# 1218 Lunt, Chicago, Il 60626
#
# 12726 Se Division St  Portland, Or 97236
# 12726 SouthEast Division St  Portland, Or 97236
# 12726 Division St  Portland, Or 97236
#
# 1434 SW Jewell Ave, Topeka, KS 66604
# 1434 SouthWest Jewell Ave, Topeka, Ks 66604
# 1434 Jewell Ave, Topeka, Ks 66604
#
# 7221 SW Macadam, Portable, OR 97219
# 7221 SouthWest Macadam, Portable, Or 97219
# 7221 Macadam, Portable, Or 97219
#
# 301 W Third St., Aberdeen, WA 98520
# 301 West Third St., Aberdeen, Wa 98520
# 301 Third St., Aberdeen, Wa 98520
#
# 112 S Camino Seco, Tucson, AZ 85710
# 112 South Camino Seco, Tucson, Az 85710
# 112 Camino Seco, Tucson, Az 85710
#
# 22 N Spruce St,  Colorado Springs, Co 80905
# 22 North Spruce St,  Colorado Springs, Co 80905
# 22 Spruce St,  Colorado Springs, Co 80905
#
# 310 Se 12th Ave, Portland, OR 97214
# 310 SouthEast 12Th Ave, Portland, Or 97214
# 310 12Th Ave, Portland, Or 97214
#
# 1004 W Royal Blvd, Boise, ID 83706
# 1004 West Royal Blvd, Boise, Id 83706
# 1004 Royal Blvd, Boise, Id 83706
#
# 1841 W 1590 S, Woods Cross, UT 84087
# 1841 West 1590 S, Woods Cross, Ut 84087
# 1841 1590 S, Woods Cross, Ut 84087
#
# 1414 W 28th St, Minneapolis, MN 55408
# 1414 West 28Th St, Minneapolis, Mn 55408
# 1414 28Th St, Minneapolis, Mn 55408
#
# 1841 W 1590 S, Woods Cross, UT 84087
# 1841 West 1590 S, Woods Cross, Ut 84087
# 1841 1590 S, Woods Cross, Ut 84087
#
# 15th ave s & s hanford st, Seattle, WA 98144
# 15Th Ave South & South Hanford St, Seattle, Wa 98144
# 15Th Ave & Hanford St, Seattle, Wa 98144
#
# 162 W 56th St, New York, NY 10029
# 162 West 56Th St, New York, Ny 10029
# 162 56Th St, New York, Ny 10029
#
# 5745 SE 17th Ave, Portland, OR 97202
# 5745 SouthEast 17Th Ave, Portland, Or 97202
# 5745 17Th Ave, Portland, Or 97202
#
# 4145 SE Olsen St, Milwaukie, OR 97222
# 4145 SouthEast Olsen St, Milwaukie, Or 97222
# 4145 Olsen St, Milwaukie, Or 97222
#
# 220 S Jackson St, Seattle, WA 98104
# 220 South Jackson St, Seattle, Wa 98104
# 220 Jackson St, Seattle, Wa 98104
#
# WinnCo 2100 s Main St, Salt Lake, UT 84115
# Winnco 2100 South Main St, Salt Lake, Ut 84115
# Winnco 2100 Main St, Salt Lake, Ut 84115
#
# 1100 S Lamar Blvd , Austin, TX 78704
# 1100 South Lamar Blvd , Austin, Tx 78704
# 1100 Lamar Blvd , Austin, Tx 78704
#
# 701 S 16th St, Tacoma, WA 98405
# 701 South 16Th St, Tacoma, Wa 98405
# 701 16Th St, Tacoma, Wa 98405
#
# Omaha, NE 68105
# Omaha, NorthEast 68105
# Omaha, 68105
#
# 9800 SE Washington st, Portland, OR 97216
# 9800 SouthEast Washington St, Portland, Or 97216
# 9800 Washington St, Portland, Or 97216
#
# 1844 sw Elise pl, Troutdale, OR 97060
# 1844 SouthWest Elise Pl, Troutdale, Or 97060
# 1844 Elise Pl, Troutdale, Or 97060
#
# 1120 14th Ave S , Seattle, WA 98144
# 1120 14Th Ave South , Seattle, Wa 98144
# 1120 14Th Ave , Seattle, Wa 98144
#
# 1545 NW 57th St., Seattle, WA 98107
# 1545 NorthWest 57Th St., Seattle, Wa 98107
# 1545 57Th St., Seattle, Wa 98107
#
# 755 S 11st , Philadelphia, PA 19147
# 755 South 11St , Philadelphia, Pa 19147
# 755 11St , Philadelphia, Pa 19147
#
# 4225 e Bellevue , Tucson, AZ 85712
# 4225 East Bellevue , Tucson, Az 85712
# 4225 Bellevue , Tucson, Az 85712
#
# 4225 e Bellevue , Tucson, AZ 85712
# 4225 East Bellevue , Tucson, Az 85712
# 4225 Bellevue , Tucson, Az 85712
#
# Wholefoods /788 S Grand Ave, Los Angeles, CA 90017, Los Angeles, CA 90017
# Wholefoods /788 South Grand Ave, Los Angeles, Ca 90017, Los Angeles, Ca 90017
# Wholefoods /788 Grand Ave, Los Angeles, Ca 90017, Los Angeles, Ca 90017
#
# 5320 NE 33rd Ave, Portland, OR 97211
# 5320 NorthEast 33Rd Ave, Portland, Or 97211
# 5320 33Rd Ave, Portland, Or 97211
#
# University of Washington Medical Center 1959 ne pacific street , Seattle, WA 98119
# University Of Washington Medical Center 1959 NorthEast Pacific Street , Seattle, Wa 98119
# University Of Washington Medical Center 1959 Pacific Street , Seattle, Wa 98119
#
# 639 S Bernardo Ave, Sunnyvale, CA 94087
# 639 South Bernardo Ave, Sunnyvale, Ca 94087
# 639 Bernardo Ave, Sunnyvale, Ca 94087
#
# 1255 S College St, Auburn, AL 36832
# 1255 South College St, Auburn, Al 36832
# 1255 College St, Auburn, Al 36832
#
# 516 S Oak Knoll Ave, Pasadena, CA 91101
# 516 South Oak Knoll Ave, Pasadena, Ca 91101
# 516 Oak Knoll Ave, Pasadena, Ca 91101
#
# SE 122nd and SE Powell, Portland, OR 97236
# Se 122Nd And SouthEast Powell, Portland, Or 97236
# Se 122Nd And Powell, Portland, Or 97236
#
# 31020 NE St, Carnation, WA 98014
# 31020 NorthEast St, Carnation, Wa 98014
# 31020 St, Carnation, Wa 98014
#
# 139 E Campbell Ave, Campbell, CA 95008
# 139 East Campbell Ave, Campbell, Ca 95008
# 139 Campbell Ave, Campbell, Ca 95008
#
# 2815 SE Hawthorne Blvd, Portland, OR 97214
# 2815 SouthEast Hawthorne Blvd, Portland, Or 97214
# 2815 Hawthorne Blvd, Portland, Or 97214
#
# 250 N Forest St., Bellingham, WA 98225
# 250 North Forest St., Bellingham, Wa 98225
# 250 Forest St., Bellingham, Wa 98225
#
# 645 Nw Portlave Ave, Bend, Or 97703
# 645 NorthWest Portlave Ave, Bend, Or 97703
# 645 Portlave Ave, Bend, Or 97703
#
# 4525 Ne Fremont St, Portland, Or 97213
# 4525 NorthEast Fremont St, Portland, Or 97213
# 4525 Fremont St, Portland, Or 97213
#
# 3843 S Lucile Street, Seattle, WA 98118
# 3843 South Lucile Street, Seattle, Wa 98118
# 3843 Lucile Street, Seattle, Wa 98118
#
# 3655 W 13th Ave, Eugene, OR 97402
# 3655 West 13Th Ave, Eugene, Or 97402
# 3655 13Th Ave, Eugene, Or 97402
#
# 4711 W Metaline Ave, Kennewick, WA 99336
# 4711 West Metaline Ave, Kennewick, Wa 99336
# 4711 Metaline Ave, Kennewick, Wa 99336
#
# Lincoln, NE 68512
# Lincoln, NorthEast 68512
# Lincoln, 68512
#
# 214 SE 8th Ave, Portland, OR 97214
# 214 SouthEast 8Th Ave, Portland, Or 97214
# 214 8Th Ave, Portland, Or 97214
#
# Boylston Ave and E Olive Way, Seattle, WA 98102
# Boylston Ave And East Olive Way, Seattle, Wa 98102
# Boylston Ave And Olive Way, Seattle, Wa 98102
#
# 4527 N Lamar blvd, Austin, TX 78751
# 4527 North Lamar Blvd, Austin, Tx 78751
# 4527 Lamar Blvd, Austin, Tx 78751
#
# 2801 NW Nela Street, Portland, OR 97210
# 2801 NorthWest Nela Street, Portland, Or 97210
# 2801 Nela Street, Portland, Or 97210
#
# 1900 Westlake Ave N  Seattle, Wa 98109
# 1900 Westlake Ave North  Seattle, Wa 98109
# 1900 Westlake Ave  Seattle, Wa 98109
#
# 500 S Los Robles Ave, Pasadena, CA 91101
# 500 South Los Robles Ave, Pasadena, Ca 91101
# 500 Los Robles Ave, Pasadena, Ca 91101
#
# N Central Ave and W Weldon Ave, Phoenix, AZ 85012
# N Central Ave And West Weldon Ave, Phoenix, Az 85012
# N Central Ave And Weldon Ave, Phoenix, Az 85012
#
# 2005 W 14Th Street  Tempe, Az 85281
# 2005 West 14Th Street  Tempe, Az 85281
# 2005 14Th Street  Tempe, Az 85281
#
# 6367 NE Radford Dr, Seattle, WA 98115
# 6367 NorthEast Radford Dr, Seattle, Wa 98115
# 6367 Radford Dr, Seattle, Wa 98115
#
# 4224 NE Halsey St, Portland, OR 97213
# 4224 NorthEast Halsey St, Portland, Or 97213
# 4224 Halsey St, Portland, Or 97213
#
# Omaha, NE 68131
# Omaha, NorthEast 68131
# Omaha, 68131
#
# Omaha, NE 68131
# Omaha, NorthEast 68131
# Omaha, 68131
#
# 1100 E 100 S, Salt Lake City, UT 84102
# 1100 East 100 S, Salt Lake City, Ut 84102
# 1100 100 S, Salt Lake City, Ut 84102
#
# 675 N Highland Ave NE, Atlanta, GA 30306
# 675 North Highland Ave Ne, Atlanta, Ga 30306
# 675 Highland Ave Ne, Atlanta, Ga 30306
#
# 201 W 76th street, New York, NY 10028
# 201 West 76Th Street, New York, Ny 10028
# 201 76Th Street, New York, Ny 10028
#
# 3108 W Washington Ave, Yakima, WA 98903
# 3108 West Washington Ave, Yakima, Wa 98903
# 3108 Washington Ave, Yakima, Wa 98903
#
# UA Cancer Center 1801 E Lee St, Tucson, AZ 85724
# Ua Cancer Center 1801 East Lee St, Tucson, Az 85724
# Ua Cancer Center 1801 Lee St, Tucson, Az 85724
#
# 3805 SE Hawthorne Blvd, Portland, OR 97202
# 3805 SouthEast Hawthorne Blvd, Portland, Or 97202
# 3805 Hawthorne Blvd, Portland, Or 97202
#
# 1959 NE Pacific St, Seattle, WA 98195
# 1959 NorthEast Pacific St, Seattle, Wa 98195
# 1959 Pacific St, Seattle, Wa 98195
#
# 621 S King St, Seattle, WA 98104
# 621 South King St, Seattle, Wa 98104
# 621 King St, Seattle, Wa 98104
#
# 702 E Desmet Ave, Spokane, WA 99202
# 702 East Desmet Ave, Spokane, Wa 99202
# 702 Desmet Ave, Spokane, Wa 99202
#
# 1288 E Hillsdale Blvd, Foster City, CA 94404
# 1288 East Hillsdale Blvd, Foster City, Ca 94404
# 1288 Hillsdale Blvd, Foster City, Ca 94404
#
# 2620 S Veitch St, Arlington, VA 22206
# 2620 South Veitch St, Arlington, Va 22206
# 2620 Veitch St, Arlington, Va 22206
#
# 4923 N Elgin, Spokane, WA 99205
# 4923 North Elgin, Spokane, Wa 99205
# 4923 Elgin, Spokane, Wa 99205
#
# 9425 S Riverside Dr Sandy, Ut 84070
# 9425 South Riverside Dr Sandy, Ut 84070
# 9425 Riverside Dr Sandy, Ut 84070
#
# 9425 S Riverside Dr Sandy, Ut 84070
# 9425 South Riverside Dr Sandy, Ut 84070
# 9425 Riverside Dr Sandy, Ut 84070
#
# 2005 N Williams, Portland, OR 97227-1929
# 2005 North Williams, Portland, Or 97227-1929
# 2005 Williams, Portland, Or 97227-1929
#
# 4900-4992 E 41st St, Tulsa, OK 74135, Tulsa, OK 74135
# 4900-4992 East 41St St, Tulsa, Ok 74135, Tulsa, Ok 74135
# 4900-4992 41St St, Tulsa, Ok 74135, Tulsa, Ok 74135
#
# 341 W 48th Street, New York, NY 10036
# 341 West 48Th Street, New York, Ny 10036
# 341 48Th Street, New York, Ny 10036
#
# 2465 NW Raleigh St, Portland, OR 97210
# 2465 NorthWest Raleigh St, Portland, Or 97210
# 2465 Raleigh St, Portland, Or 97210
#
# 3053 E Shields Ave, Fresno, CA 93726
# 3053 East Shields Ave, Fresno, Ca 93726
# 3053 Shields Ave, Fresno, Ca 93726
#
# 500 SW Twin Oaks Cir, Corvallis, OR 97333
# 500 SouthWest Twin Oaks Cir, Corvallis, Or 97333
# 500 Twin Oaks Cir, Corvallis, Or 97333
#
# 1500 NE 15th, Portland, OR 97232
# 1500 NorthEast 15Th, Portland, Or 97232
# 1500 15Th, Portland, Or 97232
#
# 306 E 12Th St, Kansas, Mo 64106
# 306 East 12Th St, Kansas, Mo 64106
# 306 12Th St, Kansas, Mo 64106
#
# Omaha, NE 68102
# Omaha, NorthEast 68102
# Omaha, 68102
#
# Omaha, NE 68102
# Omaha, NorthEast 68102
# Omaha, 68102
#
# 8600 SW 103rd Ave, Miami, FL 33173
# 8600 SouthWest 103Rd Ave, Miami, Fl 33173
# 8600 103Rd Ave, Miami, Fl 33173
#
# 5223 NE Sandy Blvd, Portland, OR 97213
# 5223 NorthEast Sandy Blvd, Portland, Or 97213
# 5223 Sandy Blvd, Portland, Or 97213
#
# Dropped pin Near Garfield Pl N E, Seattle, WA 98195
# Dropped Pin Near Garfield Pl North E, Seattle, Wa 98195
# Dropped Pin Near Garfield Pl E, Seattle, Wa 98195
#
# 7th Street NE and K Street NE, Washington, DC 20002
# 7Th Street NorthEast And K Street Ne, Washington, Dc 20002
# 7Th Street And K Street Ne, Washington, Dc 20002
#
# 909 N Bannock St., Denver, CO 80216
# 909 North Bannock St., Denver, Co 80216
# 909 Bannock St., Denver, Co 80216
#
# 7th Street NE and K Street NE, Washington, DC 20002
# ...
# 5Th Street Between F And G Street Ne, Washington, Dc 20002
#
# 5th Street NE Between F & G Street NE, Washington, DC 20002
# 5Th Street NorthEast Between F & G Street Ne, Washington, Dc 20002
# 5Th Street Between F & G Street Ne, Washington, Dc 20002
#
# 87450 E Government Camp Loop, Government Camp, OR 97028
# 87450 East Government Camp Loop, Government Camp, Or 97028
# 87450 Government Camp Loop, Government Camp, Or 97028
#
# Omaha, NE 68124
# Omaha, NorthEast 68124
# Omaha, 68124
#
# Lincoln, NE 68510
# Lincoln, NorthEast 68510
# Lincoln, 68510
#
# 160th Ave NE & NE 100th Way, Redmond, WA 98052
# 160Th Ave NorthEast & NorthEast 100Th Way, Redmond, Wa 98052
# 160Th Ave & 100Th Way, Redmond, Wa 98052
#
# 1580 NE 32nd Ave , Portland, OR 97232
# 1580 NorthEast 32Nd Ave , Portland, Or 97232
# 1580 32Nd Ave , Portland, Or 97232
#
# 200 S 3rd St, Renton, WA 98057
# 200 South 3Rd St, Renton, Wa 98057
# 200 3Rd St, Renton, Wa 98057
#
# 307 W George St, Philadelphia, PA 19123
# 307 West George St, Philadelphia, Pa 19123
# 307 George St, Philadelphia, Pa 19123
#
# Reno, NE 89502
# Reno, NorthEast 89502
# Reno, 89502
#
# Lincoln, NE 68503
# Lincoln, NorthEast 68503
# Lincoln, 68503
#
# 2401 N Oakwood Ave, Muncie, IN 47304
# 2401 North Oakwood Ave, Muncie, In 47304
# 2401 Oakwood Ave, Muncie, In 47304
#
# 375 W Erie Street, Chicago, IL 60654
# 375 West Erie Street, Chicago, Il 60654
# 375 Erie Street, Chicago, Il 60654
#
# 900 N Stuart St, Arlington, VA 22203
# 900 North Stuart St, Arlington, Va 22203
# 900 Stuart St, Arlington, Va 22203
#
# Lincoln, NE 68502
# Lincoln, NorthEast 68502
# Lincoln, 68502
#
# Lincoln, NE 68503
# Lincoln, NorthEast 68503
# Lincoln, 68503
#
# Lincoln, NE 68503
# Lincoln, NorthEast 68503
# Lincoln, 68503
#
# 5822 SE Reedway, Portland, OR 97206
# 5822 SouthEast Reedway, Portland, Or 97206
# 5822 Reedway, Portland, Or 97206
# 975 SE 11th Ave, Portland, OR 97214
# 975 SouthEast 11Th Ave, Portland, Or 97214
# 975 11Th Ave, Portland, Or 97214
#
# 65000 E HWY 26, Welches, OR 97067
# 65000 East Hwy 26, Welches, Or 97067
# 65000 Hwy 26, Welches, Or 97067
#
# 65000 E HWY 26, Welches, OR 97067
# 65000 East Hwy 26, Welches, Or 97067
# 65000 Hwy 26, Welches, Or 97067
#
# 765 E Blithedale Ave, Mill Valley, CA 94941
# 765 East Blithedale Ave, Mill Valley, Ca 94941
# 765 Blithedale Ave, Mill Valley, Ca 94941
#
# 2800 N Lakefront Trail, Chicago, IL
# 2800 North Lakefront Trail, Chicago, Il
# 2800 Lakefront Trail, Chicago, Il
#
# 13305 NE 171st st, Woodinville, WA 98072
# 13305 NorthEast 171St St, Woodinville, Wa 98072
# 13305 171St St, Woodinville, Wa 98072
#
# Kearney, NE 68845
# Kearney, NorthEast 68845
# Kearney, 68845
#
# Lincoln, NE 68504
# Lincoln, NorthEast 68504
# Lincoln, 68504
#
# 817 w Cornelia , Chicago, IL 60640
# 817 West Cornelia , Chicago, Il 60640
# 817 Cornelia , Chicago, Il 60640
#
# 2659 S Trenton Ave, Tulsa, OK 74114
# 2659 South Trenton Ave, Tulsa, Ok 74114
# 2659 Trenton Ave, Tulsa, Ok 74114
#
# N Linn st and E Market St, Iowa City, IA 52245
# N Linn St And East Market St, Iowa City, Ia 52245
# N Linn St And Market St, Iowa City, Ia 52245
#
# 3911 N 25th Street, Tacoma, WA 98406
# 3911 North 25Th Street, Tacoma, Wa 98406
# 3911 25Th Street, Tacoma, Wa 98406
#
# 7600 W Manchester Ave, Los Angeles, CA 90293
# 7600 West Manchester Ave, Los Angeles, Ca 90293
# 7600 Manchester Ave, Los Angeles, Ca 90293
#
# N Paulina Street and W Bloomingdale Ave, Chicago, IL 60622
# N Paulina Street And West Bloomingdale Ave, Chicago, Il 60622
# N Paulina Street And Bloomingdale Ave, Chicago, Il 60622
#
# Lincoln, NE 68503
# Lincoln, NorthEast 68503
# Lincoln, 68503
#
# Omaha, NE 68131
# Omaha, NorthEast 68131
# Omaha, 68131
#
# 2121 Se Belmont St,  Portland, Or 97214
# 2121 SouthEast Belmont St,  Portland, Or 97214
# 2121 Belmont St,  Portland, Or 97214
#
# 3000 E 1st Ave, Denver, CO 80206
# 3000 East 1St Ave, Denver, Co 80206
# 3000 1St Ave, Denver, Co 80206
#
# 995 E Baseline Rd, Tempe, AZ 85283
# 995 East Baseline Rd, Tempe, Az 85283
# 995 Baseline Rd, Tempe, Az 85283
#
# Omaha, NE 68122
# Omaha, NorthEast 68122
# Omaha, 68122
#
# Lincoln, NE 68512
# Lincoln, NorthEast 68512
# Lincoln, 68512
#
# 3911 n 25th , Tacoma, WA
# 3911 North 25Th , Tacoma, Wa
# 3911 25Th , Tacoma, Wa
#
# 2233 W Division , Chicago, IL 60622
# 2233 West Division , Chicago, Il 60622
# 2233 Division , Chicago, Il 60622
#
# Lincoln, NE 68504
# Lincoln, NorthEast 68504
# Lincoln, 68504
#
# Lincoln, NE 68508
# Lincoln, NorthEast 68508
# Lincoln, 68508
#
# 3000 E 1st Ave, Denver, CO 80206
# 3000 East 1St Ave, Denver, Co 80206
# 3000 1St Ave, Denver, Co 80206
#
# 251 N El Molino Ave, Pasadena, CA 91101
# 251 North El Molino Ave, Pasadena, Ca 91101
# 251 El Molino Ave, Pasadena, Ca 91101
#
# 1919 N Lynn St, Arlington, VA 22209
# 1919 North Lynn St, Arlington, Va 22209
# 1919 Lynn St, Arlington, Va 22209
#
# 660 E Wilmington Ave, B510, Salt Lake City, UT 84106
# 660 East Wilmington Ave, B510, Salt Lake City, Ut 84106
# 660 Wilmington Ave, B510, Salt Lake City, Ut 84106
#
# 845 s figueroa st, Los Angeles, CA CA
# 845 South Figueroa St, Los Angeles, Ca Ca
# 845 Figueroa St, Los Angeles, Ca Ca
#
# 1450 E Republican St, Seattle, WA 98112
# 1450 East Republican St, Seattle, Wa 98112
# 1450 Republican St, Seattle, Wa 98112
#
# 1111 NW Flanders, Portland, OR 97209
# 1111 NorthWest Flanders, Portland, Or 97209
# 1111 Flanders, Portland, Or 97209
#
# Omaha, NE 68144
# Omaha, NorthEast 68144
# Omaha, 68144
#
# Lincoln, NE 68508
# Lincoln, NorthEast 68508
# Lincoln, 68508
#
# Lincoln, NE 68503
# Lincoln, NorthEast 68503
# Lincoln, 68503
#
# Lincoln, NE 68506
# Lincoln, NorthEast 68506
# Lincoln, 68506
#
# 3924 N Wall St, Spokane, WA 99205
# 3924 North Wall St, Spokane, Wa 99205
# 3924 Wall St, Spokane, Wa 99205
#
# 126 N Berger Pkwy, Fond Du Lac, Wi 54935-3070
# 126 North Berger Pkwy, Fond Du Lac, Wi 54935-3070
# 126 Berger Pkwy, Fond Du Lac, Wi 54935-3070
#
# 13725 32Nd Ave Ne Seattle, Wa 98125
# 13725 32Nd Ave NorthEast Seattle, Wa 98125
# 13725 32Nd Ave Seattle, Wa 98125
#
# 5124 SE 17th Ave, Portland, OR 97202
# 5124 SouthEast 17Th Ave, Portland, Or 97202
# 5124 17Th Ave, Portland, Or 97202
#
# 1615 n lakeshore dr, Lake City, MN 55041
# 1615 North Lakeshore Dr, Lake City, Mn 55041
# 1615 Lakeshore Dr, Lake City, Mn 55041
#
# Omaha, NE 68104
# Omaha, NorthEast 68104
# Omaha, 68104
#
# Bellevue, NE 68123
# Bellevue, NorthEast 68123
# Bellevue, 68123
#
# E 4600 S & Adams Ave, South Ogden, UT 84403
# E 4600 South & Adams Ave, South Ogden, Ut 84403
# E 4600 & Adams Ave, South Ogden, Ut 84403
#
# 14727 W Magnolia Blvd, Los Angeles, CA 91403
# 14727 West Magnolia Blvd, Los Angeles, Ca 91403
# 14727 Magnolia Blvd, Los Angeles, Ca 91403
#
# 1111 S Plantation Dr, St. George, UT 84770
# 1111 South Plantation Dr, St. George, Ut 84770
# 1111 Plantation Dr, St. George, Ut 84770
#
# 520 2nd ave w , Seattle, WA 98119
# 520 2Nd Ave West , Seattle, Wa 98119
# 520 2Nd Ave , Seattle, Wa 98119
#
# Lincoln, NE 68506
# Lincoln, NorthEast 68506
# Lincoln, 68506
#
# Aurora, NE 68818
# Aurora, NorthEast 68818
# Aurora, 68818
#
# Omaha, NE 68105
# Omaha, NorthEast 68105
# Omaha, 68105
#
# 5820 NE SANDY BLVD, Portland, OR 97213
# 5820 NorthEast Sandy Blvd, Portland, Or 97213
# 5820 Sandy Blvd, Portland, Or 97213
#
# 1433 N Fairfield Ave , Chicago, IL 60622
# 1433 North Fairfield Ave , Chicago, Il 60622
# 1433 Fairfield Ave , Chicago, Il 60622
#
# 1906 N 44th St, Seattle, WA 98103
# 1906 North 44Th St, Seattle, Wa 98103
# 1906 44Th St, Seattle, Wa 98103
#
# 2800 SE Hawthorne Blvd, Portland, OR 97214
# 2800 SouthEast Hawthorne Blvd, Portland, Or 97214
# 2800 Hawthorne Blvd, Portland, Or 97214
#
# 760 N 7TH ST , San Jose, CA 95112
# 760 North 7Th St , San Jose, Ca 95112
# 760 7Th St , San Jose, Ca 95112
#
# Lincoln, NE 68508
# Lincoln, NorthEast 68508
# Lincoln, 68508
#
# Fernley, NE 89408
# Fernley, NorthEast 89408
# Fernley, 89408
#
# Chadron, NE 69337
# Chadron, NorthEast 69337
# Chadron, 69337
#
# Bridgeport, NE 69336
# Bridgeport, NorthEast 69336
# Bridgeport, 69336
#
# 1301 w 5th st, Austin, TX 78703
# 1301 West 5Th St, Austin, Tx 78703
# 1301 5Th St, Austin, Tx 78703
#
# 1285 N Clarkson St., Denver, CO 80218
# 1285 North Clarkson St., Denver, Co 80218
# 1285 Clarkson St., Denver, Co 80218
#
# 1800 W Fairview Ave, Boise, ID 83702
# 1800 West Fairview Ave, Boise, Id 83702
# 1800 Fairview Ave, Boise, Id 83702
#
# 401 n Riverpoint blvd, Spokane, WA 99202
# 401 North Riverpoint Blvd, Spokane, Wa 99202
# 401 Riverpoint Blvd, Spokane, Wa 99202
#
# 401 n Riverpoint blvd, Spokane, WA 99202
# 401 North Riverpoint Blvd, Spokane, Wa 99202
# 401 Riverpoint Blvd, Spokane, Wa 99202
#
# E pennigton st & E toole, Tucson, AZ 85719
# E Pennigton St & East Toole, Tucson, Az 85719
# E Pennigton St & Toole, Tucson, Az 85719
#
# 817 S 5th Ave, Minneapolis, MN 55404
# 817 South 5Th Ave, Minneapolis, Mn 55404
# 817 5Th Ave, Minneapolis, Mn 55404
#
# 7115 NE Prescott, Portland, OR 97218
# 7115 NorthEast Prescott, Portland, Or 97218
# 7115 Prescott, Portland, Or 97218
#
# S Lafayette St & E Cedar Ave, Denver, CO 80209
# S Lafayette St & East Cedar Ave, Denver, Co 80209
# S Lafayette St & Cedar Ave, Denver, Co 80209
#
# 183 E Main Street, Rochester, NY 14604
# 183 East Main Street, Rochester, Ny 14604
# 183 Main Street, Rochester, Ny 14604
#
# 1615 n lakeshore dr. , Lake City, MN 55041
# 1615 North Lakeshore Dr. , Lake City, Mn 55041
# 1615 Lakeshore Dr. , Lake City, Mn 55041
#
# 2500 E 8th St, Austin, TX 78702
# 2500 East 8Th St, Austin, Tx 78702
# 2500 8Th St, Austin, Tx 78702
#
# 142 E 2100 S, Salt Lake City, UT 84115
# 142 East 2100 S, Salt Lake City, Ut 84115
# 142 2100 S, Salt Lake City, Ut 84115
#
# 2405 Ave N Lubbock, Tx 79411
# 2405 Ave North Lubbock, Tx 79411
# 2405 Ave Lubbock, Tx 79411
#
# 64th Ave and Francis St, Omaha, NE 68106
# 64Th Ave And Francis St, Omaha, NorthEast 68106
# 64Th Ave And Francis St, Omaha, 68106
#
# 7701 W 6th Ave, Lakewood, CO 80214
# 7701 West 6Th Ave, Lakewood, Co 80214
# 7701 6Th Ave, Lakewood, Co 80214
#
# 450 mass ave nw , Washington, DC 20001
# 450 Mass Ave NorthWest , Washington, Dc 20001
# 450 Mass Ave , Washington, Dc 20001
#
# 209 W 97TH ST, New York, NY 10025
# 209 West 97Th St, New York, Ny 10025
# 209 97Th St, New York, Ny 10025
#
# 2305 N Prospect Ave, Milwaukee, WI 53211
# 2305 North Prospect Ave, Milwaukee, Wi 53211
# 2305 Prospect Ave, Milwaukee, Wi 53211
#
# 501 N Dubuque Street, Iowa City, IA 52245
# 501 North Dubuque Street, Iowa City, Ia 52245
# 501 Dubuque Street, Iowa City, Ia 52245
#
# 600 S Clyde Morris Blvd, Daytona Beach, FL 33615
# 600 South Clyde Morris Blvd, Daytona Beach, Fl 33615
# 600 Clyde Morris Blvd, Daytona Beach, Fl 33615
#
# 3911 N 25th St, Tacoma, WA 98406
# 3911 North 25Th St, Tacoma, Wa 98406
# 3911 25Th St, Tacoma, Wa 98406
#
# 3911 N 25th St, Tacoma, WA 98406
# 3911 North 25Th St, Tacoma, Wa 98406
# 3911 25Th St, Tacoma, Wa 98406
#
# 3911 N 25th St, Tacoma, WA 98406
# 3911 North 25Th St, Tacoma, Wa 98406
# 3911 25Th St, Tacoma, Wa 98406
#
# 3911 N 25th St, Tacoma, WA 98406
# 3911 North 25Th St, Tacoma, Wa 98406
# 3911 25Th St, Tacoma, Wa 98406
#
# 4101 E Belleview St Phoenix, Az 85008
# 4101 East Belleview St Phoenix, Az 85008
# 4101 Belleview St Phoenix, Az 85008
#
# 852 W Lill Ave, Chicago, IL 60614
# 852 West Lill Ave, Chicago, Il 60614
# 852 Lill Ave, Chicago, Il 60614
#
# E Webster & N Prospect, Milwaukee, WI 53211
# E Webster & North Prospect, Milwaukee, Wi 53211
# E Webster & Prospect, Milwaukee, Wi 53211
#
# 401 SE Main St, Minneapolis, MN 55414
# 401 SouthEast Main St, Minneapolis, Mn 55414
# 401 Main St, Minneapolis, Mn 55414
#
# 205 N Broadway, Aurora, IN 60505
# 205 North Broadway, Aurora, In 60505
# 205 Broadway, Aurora, In 60505
#
# 615 SE Main St, Portland, OR 97215
# 615 SouthEast Main St, Portland, Or 97215
# 615 Main St, Portland, Or 97215
#
# 1720 SW 4th Ave Cyan PDX garage, Portland, OR 97201
# 1720 SouthWest 4Th Ave Cyan Pdx Garage, Portland, Or 97201
# 1720 4Th Ave Cyan Pdx Garage, Portland, Or 97201
#
# 1202 Lakeview Blvd E Seattle, Wa 98102
# 1202 Lakeview Blvd East Seattle, Wa 98102
# 1202 Lakeview Blvd Seattle, Wa 98102
#
# 1156 N 198th St., Shoreline, WA 98133
# 1156 North 198Th St., Shoreline, Wa 98133
# 1156 198Th St., Shoreline, Wa 98133
#
# 3330 SE Division st., Portland, OR 97202
# 3330 SouthEast Division St., Portland, Or 97202
# 3330 Division St., Portland, Or 97202
#
# 9401 NE Sunderland Ave, Portland, OR 97211
# 9401 NorthEast Sunderland Ave, Portland, Or 97211
# 9401 Sunderland Ave, Portland, Or 97211
#
# 567 NE 8th St, Gresham, OR 97030, USA, Gresham, OR 970305649
# 567 NorthEast 8Th St, Gresham, Or 97030, Usa, Gresham, Or 970305649
# 567 8Th St, Gresham, Or 97030, Usa, Gresham, Or 970305649
#
# 870 E El Camino Real  Mountain View, Ca 94040
# 870 East El Camino Real  Mountain View, Ca 94040
# 870 El Camino Real  Mountain View, Ca 94040
#
# 5525 Cedar Lake Rd S St. Louis Park, Mn 55416
# 5525 Cedar Lake Rd South St. Louis Park, Mn 55416
# 5525 Cedar Lake Rd St. Louis Park, Mn 55416
#
# 1351 SW Arvonia Pl, Topeka, KS 66615
# 1351 SouthWest Arvonia Pl, Topeka, Ks 66615
# 1351 Arvonia Pl, Topeka, Ks 66615
#
# Omaha, NE 68106
# Omaha, NorthEast 68106
# Omaha, 68106
#
# 714 W IVANHOE RD, Spokane, WA 99218-2237
# 714 West Ivanhoe Rd, Spokane, Wa 99218-2237
# 714 Ivanhoe Rd, Spokane, Wa 99218-2237
#
# 915 NW 45th St, Seattle, WA 908107
# 915 NorthWest 45Th St, Seattle, Wa 908107
# 915 45Th St, Seattle, Wa 908107
#
# 4219 s othello st, Seattle, WA 98118
# 4219 South Othello St, Seattle, Wa 98118
# 4219 Othello St, Seattle, Wa 98118
#
# 1800, N Oak St, Arlington, VA 22209
# 1800, North Oak St, Arlington, Va 22209
# 1800, Oak St, Arlington, Va 22209
#
# 3400 25Th Ave W Seattle, Wa 98199
# 3400 25Th Ave West Seattle, Wa 98199
# 3400 25Th Ave Seattle, Wa 98199
#
# 1101 S Wabash Ave, Chicago, IL 60605
# 1101 South Wabash Ave, Chicago, Il 60605
# 1101 Wabash Ave, Chicago, Il 60605
#
# 900 E 9Th St Muscatine, Ia 52761
# 900 East 9Th St Muscatine, Ia 52761
# 900 9Th St Muscatine, Ia 52761
#
# 450 NE 71st St, Seattle, WA 98115
# 450 NorthEast 71St St, Seattle, Wa 98115
# 450 71St St, Seattle, Wa 98115
#
# 414 E 7th Ave, Spokane, WA 99202
# 414 East 7Th Ave, Spokane, Wa 99202
# 414 7Th Ave, Spokane, Wa 99202
#
# 107 N Cook Street, Portland, OR 97227
# 107 North Cook Street, Portland, Or 97227
# 107 Cook Street, Portland, Or 97227
#
# 14679 NE 95th St, Redmond, WA 98052
# 14679 NorthEast 95Th St, Redmond, Wa 98052
# 14679 95Th St, Redmond, Wa 98052
#
# 1781 N 23rd Street, Washougal, WA 98671
# 1781 North 23Rd Street, Washougal, Wa 98671
# 1781 23Rd Street, Washougal, Wa 98671
#
# chesapeake street, NW DC, Washington, DC 20016
# Chesapeake Street, NorthWest Dc, Washington, Dc 20016
# Chesapeake Street, Dc, Washington, Dc 20016
#
# 2018 NW IRVING, Portland, OR 97209
# 2018 NorthWest Irving, Portland, Or 97209
# 2018 Irving, Portland, Or 97209
#
# 2018 NW IRVING, Portland, OR 97209
# 2018 NorthWest Irving, Portland, Or 97209
# 2018 Irving, Portland, Or 97209
#
# 4725 SE Division , Portland, OR 97206
# 4725 SouthEast Division , Portland, Or 97206
# 4725 Division , Portland, Or 97206
#
# 2497 Se Burnside Rd, Gresham, OR 9708
# 2497 SouthEast Burnside Rd, Gresham, Or 9708
# 2497 Burnside Rd, Gresham, Or 9708
#
# 909 S 30th Avenue, Yakima, WA 98902
# 909 South 30Th Avenue, Yakima, Wa 98902
# 909 30Th Avenue, Yakima, Wa 98902
#
# 909 S 30th Avenue, Yakima, WA 98902
# 909 South 30Th Avenue, Yakima, Wa 98902
# 909 30Th Avenue, Yakima, Wa 98902
#
# 101 10th St. E , St. Paul, MN 55101
# 101 10Th St. East , St. Paul, Mn 55101
# 101 10Th St. , St. Paul, Mn 55101
#
# 5322 W 119th Ter, Overland Park, KS 66209
# 5322 West 119Th Ter, Overland Park, Ks 66209
# 5322 119Th Ter, Overland Park, Ks 66209
#
# Se 14th ave and se stark st, Portland, OR 97214
# Se 14Th Ave And SouthEast Stark St, Portland, Or 97214
# Se 14Th Ave And Stark St, Portland, Or 97214
#
# 750 S Vance St, Lakewook, CO 80226
# 750 South Vance St, Lakewook, Co 80226
# 750 Vance St, Lakewook, Co 80226
#
# 2723 N Houghton St, Portland, OR 97217
# 2723 North Houghton St, Portland, Or 97217
# 2723 Houghton St, Portland, Or 97217
#
# 5765 W Broadway, Missoula, MT 59808
# 5765 West Broadway, Missoula, Mt 59808
# 5765 Broadway, Missoula, Mt 59808
#
# 854 E holt ave, Bayview, WI
# 854 East Holt Ave, Bayview, Wi
# 854 Holt Ave, Bayview, Wi
#
# 2537 S Americus St, Seattle, WA 98108
# 2537 South Americus St, Seattle, Wa 98108
# 2537 Americus St, Seattle, Wa 98108
#
# 1123 E 10TH ST, Tucson, AZ 85719
# 1123 East 10Th St, Tucson, Az 85719
# 1123 10Th St, Tucson, Az 85719
#
# 1500 E Park Place, Milwaukee, WI 53211
# 1500 East Park Place, Milwaukee, Wi 53211
# 1500 Park Place, Milwaukee, Wi 53211
#
# 6267 NE Radford Dr., Seattle, WA 98115
# 6267 NorthEast Radford Dr., Seattle, Wa 98115
# 6267 Radford Dr., Seattle, Wa 98115
#
# 7018 e sprague, Spokane Valley, WA 99212
# 7018 East Sprague, Spokane Valley, Wa 99212
# 7018 Sprague, Spokane Valley, Wa 99212

# %%
def find_locations(df_in):
    """
    Insert dataframe with modified location columns, will query photon and nomanatim to get locations
    Returns modified dataframe and list of problem addresses for further investigation.
    Note: Cannot be multi-threaded, or will break the TOS of both geocoders used.
    """
    
    df_loc_found=df_in.copy()
    
    #Prep some blank columns for the longitudes and latitudes
    df_loc_found['Latitude']='None'
    df_loc_found['Longitude']='None'
    df_loc_found['Address']='None'
    
    #Initialize the geocoders - will be used to find the locations. 
    geolocator_nominatim = Nominatim(user_agent="BikeThefts")
    geolocator_photon = Photon(user_agent="BikeThefts")
    
    #Captures
    problems=[]
    nominatim_interval=time.perf_counter() #Nominatim need a minimum of 1s between queries per its TOS
    
    for i in tqdm(range(df_loc_found.shape[0])):
        
        #Only search full addresses - the location of a city center is not useful.
        if df_loc_found['Full Address'].iloc[i] == True: #Else, pass (below)
            
            #First, try Photon - has the best success rate
            try:
                #Query Photon on the full modified address
                address=df_loc_found['Modified Location'].iloc[i]
                location = geolocator_photon.geocode(address)
                
                df_loc_found['Latitude'].iloc[i]  = location.latitude
                df_loc_found['Longitude'].iloc[i] = location.longitude
                df_loc_found['Address'].iloc[i]   = location.address
            
    
            except:
                #Then try Nominatim
                try:
                    #Required interval between requests for Nominatim's TOS
                    t = time.perf_counter()
                    if (t - nominatim_interval) < 1:
                        time.sleep((t - nominatim_interval))
                    
                    address=df_loc_found['Modified Location'].iloc[i]
                    
                    location = geolocator_nominatim.geocode(address)
                    
                    df_loc_found['Latitude'].iloc[i]  = location.latitude
                    df_loc_found['Longitude'].iloc[i] = location.longitude
                    df_loc_found['Address'].iloc[i]   = location.address
                    
                    #Reset the nominatim countdown
                    nominatim_interval=time.perf_counter()
                    
                except:
                    #Need to reset the nominatim countdown anyways
                    nominatim_interval=time.perf_counter()
                    
                    #Then try Photon on the abbreviated address
                    try:
                        address=df_loc_found['Modified Shortened Location'].iloc[i]
                        
                        location = geolocator_photon.geocode(address)
                        
                        df_loc_found['Latitude'].iloc[i]  = location.latitude
                        df_loc_found['Longitude'].iloc[i] = location.longitude
                        df_loc_found['Address'].iloc[i]   = location.address
            
                    
                    except:
                        #Don't try Nominatim for the final round - unlikely to work, and adds 1s/search
                        problems.append(df_loc_found['Modified Location'].iloc[i])
                        
    
    return df_loc_found, problems

# %%
#Enable the command below to run the locator on the full data set.
#This will take 2+ hours, for the full dataset, and cannot be sped up due to the geolocators Terms of Service.
#df_loc_found, problems = find_locations(df_loc)

#This is a demo, showing the locator on a small samples.
df_loc_found, problems = find_locations(df_loc.tail(10))
df_loc_found.head(10)
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]C:\Users\Mariko\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  6.91it/s]
#        Bike ID                            Location Locking description  \
# 75698   769032                Santa Cruz, CA 95060              U-lock
# 75699   703109             Santa Barbara, CA 93105          Not locked
# 75700   661112                       Troutdale, OR                None
# 75701   763280          127th & 45, Palos Park, IL                None
# 75702   736397  521 Texas Street, Denton, TX 76209          Not locked
# 75703   764139                Buena Park, CA 90620                None
# 75704   763245             San Francisco, CA 94114              U-lock
# 75705   732692             BART Train, Oakland, CA          Not locked
# 75706   759463             San Francisco, CA 94110          Not locked
# 75707   763500                   Buffalo, NY 14216               Other
#
#                        Locking circumvented Date stolen  ...  \
# 75698  Lock is missing, along with the bike   2020.6.16  ...
# 75699                   Bike was not locked   2020.6.16  ...
# 75700                                  None   2020.6.16  ...
# 75701                                  None   2020.6.15  ...
# 75702  Lock is missing, along with the bike   2020.6.15  ...
# 75703                                  None   2020.6.15  ...
# 75704   Lock was cut, and left at the scene   2020.6.15  ...
# 75705                                  None   2020.6.15  ...
# 75706                   Bike was not locked   2020.6.15  ...
# 75707                                  None   2020.6.15  ...
#
#                         Modified Location         Modified Shortened Location  \
# 75698                Santa Cruz, CA 95060                Santa Cruz, CA 95060
# 75699             Santa Barbara, CA 93105             Santa Barbara, CA 93105
# 75700                       Troutdale, OR                       Troutdale, OR
# 75701          127th & 45, Palos Park, IL          127th & 45, Palos Park, IL
# 75702  521 Texas Street, Denton, TX 76209  521 Texas Street, Denton, TX 76209
# 75703                Buena Park, CA 90620                Buena Park, CA 90620
# 75704             San Francisco, CA 94114             San Francisco, CA 94114
# 75705             BART Train, Oakland, CA             BART Train, Oakland, CA
# 75706             San Francisco, CA 94110             San Francisco, CA 94110
# 75707                   Buffalo, NY 14216                   Buffalo, NY 14216
#
#       Latitude Longitude                                            Address
# 75698     None      None                                               None
# 75699     None      None                                               None
# 75700     None      None                                               None
# 75701  41.6603  -87.8173  West 127th Street, 60464, Palos Park, Illinois...
# 75702  33.2139  -97.1447  Denton TX LDS Institute, West Mulberry Street,...
# 75703     None      None                                               None
# 75704     None      None                                               None
# 75705  37.8049  -122.295  West Oakland, West Oakland BART Plaza, 94626, ...
# 75706     None      None                                               None
# 75707     None      None                                               None
#
# [10 rows x 15 columns]

# %%
"""
Save the database

"""
#Save the dataframe to file if you ran the entire database, else don't overwrite the imported dataframe.
#df_loc_found.to_csv(f'./Data/Main_Database.csv')

# %% [markdown]
# ## Updater Function

# %%
"""
Load the database from file

"""
main_df = pd.read_csv(f'./Data/Main_Database.csv', index_col=0,  parse_dates=['DateTime'])

# %%
def update_get_urls(page_url, main_df):
    """
    Query a page of the stolen bikes, and check if urls are from US, and if any reports
    have already been downloaded. 
    Return a flag indicating if a repeat occured.
    """
    
    #Flag for tracking if bikes already present
    reoccur_flag=0
    
    #Download the page
    page = requests.get(page_url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #Get the table of bike thefts, and look through by theft
    results = soup.find_all("div", {"class":"bike-information multi-attr-lists"})
    
    clean_urls=[]
    
    #Check to make sure the location is present in the theft report
    for result in results:
        theft_location= result.find(string=re.compile('Location')).parent.next_sibling
        
        #Theft reports always terminate in country code, and if location is only "US", there is no - .
        if '- US' in theft_location:
            
            bike_url=result.find('a').get('href')
            
            #Check if bike already in database, and if not capture URL
            try: 
                bike_ID= int(bike_url.split('/bikes/')[1])
    
                if bike_ID in main_df['Bike ID'].values:
                    reoccur_flag = 1
                else:
                    clean_urls.append(bike_url)
            except:
                pass


    return clean_urls, reoccur_flag



def update_bikes_downloader(main_df):
    """
    Download all the bikes per search page that have a US location listed
    Does not download non-us or non location specified thefts
    """
    
    reoccur_flag=0
    
    
    #First page has slightly different url
    page_url = 'https://bikeindex.org/bikes?&stolenness=all'
    
    #Get page URLs, as long as they are new
    url_list, reoccur_flag = update_get_urls(page_url, main_df)
    
    #Download the batch of urls
    df_page=download_batch_url(url_list)
    
    i=2
    while reoccur_flag == 0:
        
        print(f'........\nNow downloading page {i}\n........')
        page_url = 'https://bikeindex.org/bikes?page='+str(i)+'&stolenness=all'
    
        #Get page URLs, as long as they are new
        url_list, reoccur_flag = update_get_urls(page_url, main_df)
        
        #Download the batch of urls
        try:
            df_page=pd.concat([df_page, download_batch_url(url_list)])
        except:
            print(f'........\nError on page {i}\n........')
    

        i+=1
    
    #Check if there are any downloaded files first
    if df_page.shape[0] >0 :
        
        #For privacy, change the report number to a binary value
        df_page['Police report'] = df_page['Police report'] != 'None'
        df_page['Police report'] = df_page['Police report'].replace({True:'Reported', False:'None'})

    
    return df_page



def update_bikes(main_df):
    """
    Downloads new bike thefts and updates the database of bike thefts
    Stops downloading when it encounters previously downloaded thefts.    
    """
    
    df_new = update_bikes_downloader(main_df)

    #Only do processing if new files were downloaded    
    if df_new.shape[0] > 0:
                
        #Clean IDS and Addresses
        df_new=clean_bike_IDs(df_new)
        df_new=clean_address(df_new)
        df_new=add_datetime(df_new)
        
        #Remove common appartment number issues and elongate directions
        df_new["Modified Location"] = remove_apartments(df_new["Location"].tolist())
        df_new["Modified Location"], df_new["Modified Shortened Location"] = modify_directions(df_new["Modified Location"].tolist())
        
        #Find the exact lat and longitude
        df_new, problems = find_locations(df_new)
    
        #Concatinate with the main database and save
        main_df = pd.concat([main_df, df_new])
        main_df.to_csv(f'./Data/Main_Database.csv')

    print(f'\n ------------- \n\n Your Database is now up to date.\n\n ------------- \n')

    return main_df

# %%
#Run the updater to get the database up to date, 
#Runs all the cleaning an processing steps, 
#Returns the complete database.

df=update_bikes(main_df)
# Out:
# ........
# Now downloading page 2
# ........
# ........
# Now downloading page 3
# ........
# ........
# Now downloading page 4
# ........
# ........
# Now downloading page 5
# ........
# ........
# Now downloading page 6
# ........
# ........
# Now downloading page 7
# ........
# ........
# Now downloading page 8
# ........
# ........
# Now downloading page 9
# ........
# ........
# Now downloading page 10
# ........
# ........
# Now downloading page 11
# ........
# ........
# Now downloading page 12
# ........
#   0%|                                                                                           | 0/90 [00:00<?, ?it/s]
# Apartments with the word Apartment or Unit
# ---------------------
#
# 1805 Anderson Rd Apt 56, Davis, CA 95616
# 1805 Anderson Rd Davis, Ca 95616
#
# 9827 West 79th , Apt 1006, Overland Park, KS 66204
# 9827 West 79Th , Overland Park, Ks 66204
#
#
# Apartments with the prefix #_____
# ---------------------
#
#
# Apartments with format , #### ,
# ---------------------
#
#
# Apartments with the word Ste (studio/suite)
# ---------------------
#
#
# Addresses with Directional Abbreviations
# ---------------------
#
# E colonial and N goldenrod, Orlando, FL 32807
# E Colonial And North Goldenrod, Orlando, Fl 32807
# E Colonial And Goldenrod, Orlando, Fl 32807
#
# 232 N Main St, Kaysville, UT 84037
# 232 North Main St, Kaysville, Ut 84037
# 232 Main St, Kaysville, Ut 84037
#
# 708 W 10th ave, Stillwater, OK 74074
# 708 West 10Th Ave, Stillwater, Ok 74074
# 708 10Th Ave, Stillwater, Ok 74074
#
# 33 W St. NW, Washington, DC 20001
# 33 West St. Nw, Washington, Dc 20001
# 33 St. Nw, Washington, Dc 20001
#
# 874 E I-10 service rd, Slidell, LA 7461
# 874 East I-10 Service Rd, Slidell, La 7461
# 874 I-10 Service Rd, Slidell, La 7461
# 100%|██████████████████████████████████████████████████████████████████████████████████| 90/90 [00:14<00:00,  6.13it/s]
#  -------------
#
#  Your Database is now up to date.
#
#  -------------

# %%
df.sort_values(by='DateTime', ascending=False).head()
# Out:
#    Bike ID                                  Location Locking description  \
# 1   835856                         Manteca, CA 95337                None
# 0   959762                          Austin, TX 78757                None
# 2   959748  1805 Anderson Rd Apt 56, Davis, CA 95616          Cable lock
# 3   959723                          Boston, MA 02134                None
# 4   958095            Burke road, Pasadena, TX 77506               Other
#
#                    Locking circumvented Date stolen  ...  \
# 1                                  None  2020.12.14  ...
# 0                                  None  2020.12.14  ...
# 2  Lock is missing, along with the bike  2020.12.14  ...
# 3                                  None  2020.12.14  ...
# 4                   Bike was not locked  2020.12.14  ...
#
#         Modified Shortened Location  Latitude Longitude  \
# 1                 Manteca, CA 95337      None      None
# 0                  Austin, TX 78757      None      None
# 2  1805 Anderson Rd Davis, Ca 95616   38.5473  -121.759
# 3                  Boston, MA 02134      None      None
# 4    Burke road, Pasadena, TX 77506   29.6992  -95.1828
#
#                                              Address   DateTime
# 1                                               None 2020-12-14
# 0                                               None 2020-12-14
# 2  Anderson Road, Davis, Yolo County, California,... 2020-12-14
# 3                                               None 2020-12-14
# 4  Burke Road, 77506, Pasadena, Texas, United Sta... 2020-12-14
#
# [5 rows x 15 columns]
